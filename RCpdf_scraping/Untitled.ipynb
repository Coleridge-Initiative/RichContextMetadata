# %%
java -Xmx6g -jar tools/science-parse-cli-assembly-2.0.2-SNAPSHOT.jar -o ../data/input/files/json/ ../data/input/files/pdf/

# %%
import download_corpus_resources

# %%
# import pdfminer2
from tika import parser

# %%
import os
pdfs = os.listdir("resources/pubs/pdf")
# path_name = "resources/pubs/pdf/" + pdfs[0]

# %%
path_name = "resources/pubs/pdf/c0dd348c36f849716f71.pdf"

# %%
rawText = parser.from_file(path_name)

# %%
rawList = rawText['content'].splitlines()

# %%
text_data = [a for a in rawList if a not in ['',' ']]

# %%
text_data
# Out:
# ['Health Behaviors among Low-income Hispanic and Non-Hispanic White Women',
#  'Food Science and Human Nutrition Publications Food Science and Human Nutrition',
#  '5-1-2018',
#  'Health Behaviors among Low-income Hispanic',
#  'and Non-Hispanic White Women',
#  'Donna M. Winham',
#  'Iowa State University, dwinham@iastate.edu',
#  'Shelly M. Palmer',
#  'Iowa State University',
#  'Traci L. Armstrong Florian',
#  'University of Arizona',
#  'Mack C. Shelley',
#  'Iowa State University, mshelley@iastate.edu',
#  'Follow this and additional works at: https://lib.dr.iastate.edu/fshn_hs_pubs',
#  'Part of the Family, Life Course, and Society Commons, Food Chemistry Commons, Human and',
#  'Clinical Nutrition Commons, International and Community Nutrition Commons, International',
#  "Relations Commons, and the Women's Studies Commons",
#  'The complete bibliographic information for this item can be found at https://lib.dr.iastate.edu/',
# ...

# %%
rawText['content']
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHealth Behaviors among Low-income Hispanic and Non-Hispanic White Women\n\n\nFood Science and Human Nutrition Publications Food Science and Human Nutrition\n\n5-1-2018\n\nHealth Behaviors among Low-income Hispanic\nand Non-Hispanic White Women\nDonna M. Winham\nIowa State University, dwinham@iastate.edu\n\nShelly M. Palmer\nIowa State University\n\nTraci L. Armstrong Florian\nUniversity of Arizona\n\nMack C. Shelley\nIowa State University, mshelley@iastate.edu\n\nFollow this and additional works at: https://lib.dr.iastate.edu/fshn_hs_pubs\nPart of the Family, Life Course, and Society Commons, Food Chemistry Commons, Human and\n\nClinical Nutrition Commons, International and Community Nutrition Commons, International\nRelations Commons, and the Women's Studies Commons\n\nThe complete bibliographic information for this item can be found at https://lib.dr.iastate.edu/\nfshn_hs_pubs/28. For information on how 
# ...
