# %%
import re
import sys
import codecs
import json
from collections import defaultdict
from difflib import SequenceMatcher
from pprint import pprint
from fuzzywuzzy import fuzz
from datasketch import MinHashLSHEnsemble, MinHash
from sklearn import metrics

KNOWN = 1
UNKNOWN = 0

def title_match(title1, title2):
    pass

def get_set_of_words(text):
    return re.sub("[\W+]", " ", text).lower().split()

def run_model(adrf_dataset_list, rc_corpus, lsh_threshold, classified_ids,debug=False):

    print("creating MinHashLSHEnsemble with threshold=%s, num_perm=128, num_part=16..." % lsh_threshold)
    # Create an LSH Ensemble index with threshold and number of partition settings.
    lshensemble = MinHashLSHEnsemble(threshold=lsh_threshold, num_perm=128, num_part=16)

    print("indexing all RC dataset's MinHash...")
    # Index takes an iterable of (key, minhash, size)
    lshensemble.index([(key, values["min_hash"], len(values["words"])) for key, values in rc_corpus.items()])

    # test by querying the LSH Ensemble with each ADRF dataset title to explore potential matches
    results = list()
    for adrf_dataset in adrf_dataset_list:
        if adrf_dataset["fields"]["dataset_id"] not in classified_ids:
            continue
        set1 = get_set_of_words(adrf_dataset["fields"]["title"])
        m1 = MinHash(num_perm=128)
        for term in set1:
            m1.update(term.encode("utf8"))

        #print("\nquery for '%s' yields datasets" % adrf_dataset["fields"]["title"])
        matches = False
        for key in lshensemble.query(m1, len(set1)):
            #print(key, rc_corpus[key]["title"])
            matches = True
            break
        if matches:
            results.append(KNOWN)
        else:
            results.append(UNKNOWN)
            #print("no matches")

    return results


def load_test_vector(adrf_dataset_list,true_links, true_not_links): ## TODO: this is partially built

    vector = list()
    classified = list()
    for adrf_dataset in adrf_dataset_list:
        if adrf_dataset["fields"]["dataset_id"] in true_links:
            vector.append(KNOWN)
            classified.append(adrf_dataset["fields"]["dataset_id"])
        elif adrf_dataset["fields"]["dataset_id"] in true_not_links:
            vector.append(UNKNOWN)
            classified.append(adrf_dataset["fields"]["dataset_id"])

    return vector,classified


def create_test_vector(rc_dataset_list,adrf_dataset_list):

    true_links = set()
    true_not_links = set()

    for adrf_dataset in adrf_dataset_list:
        title = adrf_dataset["fields"]["title"]
        url = adrf_dataset["fields"]["source_url"]
        adrf_id = adrf_dataset["fields"]["dataset_id"]

        # Excluding by provider (manual search) ## TODO: subject to change!
        if adrf_dataset["fields"]["data_provider"] in [6,7,12,14,17,48,44,40]: #other providers ID would be 30, 29, 26, 23,22,19,18,17,15
            true_not_links.add(adrf_id)
            continue

        # TODO: check manually from https://github.com/NYU-CI/RCCustomers/blob/5e71284c893f39e670a474ec9b7110ec04593e09/customers/USDA/bin/usda_datadump.json
        if title in [
            "Information Resources, Inc. (IRI) Consumer Network household-based scanner data",
            "Information Resources, Inc. (IRI) InfoScan retail-based scanner data",
            "FoodAPS National Household Food Acquisition and Purchase Survey",
            "Supplemental Nutrition Assistance Program (SNAP) Administrative Data"
                    ]:
            true_links.add(adrf_id)
            continue

        for rc_dataset in rc_dataset_list:
            if "adrf_id" in rc_dataset and adrf_id == rc_dataset["adrf_id"]:
                true_links.add(adrf_id)
                continue

            if "title" in rc_dataset and title == rc_dataset["title"]:
                true_links.add(adrf_id)
                continue

            if "url" in rc_dataset and url == rc_dataset["url"]:
                true_links.add(adrf_id)
                continue

            #if rc_dataset["id"] in ["dataset-002","dataset-001"]


    return true_links, true_not_links

def get_confusion_matrix_scores(test_vector, result):
    tn, fp, fn, tp = metrics.confusion_matrix(test_vector, result).ravel()

    scores = dict()
    confusion_matrix = dict()
    confusion_matrix["TN"] = tn
    confusion_matrix["FP"] = fp
    confusion_matrix["FN"] = fn
    confusion_matrix["TP"] = tp
    scores["confusion_matrix"] = confusion_matrix
    scores["accuracy_score"] = metrics.accuracy_score(test_vector, result)
    scores["recall_score"] = metrics.recall_score(test_vector, result)
    scores["precision_score"] = metrics.precision_score(test_vector,result)
    scores["f1_score"] = metrics.f1_score(test_vector, result) # harmonic mean of Precision and Recall
    scores["specificity_score"] = tn / (tn + fp)
    scores["False Positive Rate or Type I Error"] = fp / (fp + tn)
    scores["False Negative Rate or Type II Error"] = fn / (fn + tp)
    return scores


def main(corpus_path, search_for_matches_path):

    ## TODO: Create known true matches and known false matches lists
        # TODO: for 4 true links see https://github.com/NYU-CI/RCCustomers/blob/5e71284c893f39e670a474ec9b7110ec04593e09/customers/USDA/bin/usda_datadump.json

    #Load all dataset adrf_ids and titles from ADRF dump
    with codecs.open(search_for_matches_path, "r", encoding="utf8") as f:
        adrf_dataset_list = json.load(f)

    print("loading ADRF dataset corpus...", type(adrf_dataset_list), len(adrf_dataset_list))

    # Load all dataset ids and titles from dataset.json
        #TODO using a temporal copy instead the most updated version˚
    with codecs.open(corpus_path, "r", encoding="utf8") as f:
        rc_dataset_list = json.load(f)

    print("loading RC dataset corpus...",type(rc_dataset_list),len(rc_dataset_list))

    # create a structure to access title and its set of unique words
    rc_corpus = defaultdict()
    for dataset in rc_dataset_list:
        d = dict()
        d["words"] = get_set_of_words(dataset["title"])
        d["title"] = dataset["title"]
        rc_corpus[dataset["id"]] = d

    # create a MinHash for each dataset title
    print("creating MinHash for each RC dataset...")
    for key,values in rc_corpus.items():
        mh = MinHash(num_perm=128)
        for term in values["words"]:
            mh.update(term.encode("utf8"))
        rc_corpus[key]["min_hash"] = mh

    true_links, true_not_links = create_test_vector(rc_dataset_list, adrf_dataset_list)

    test_vector,classified_ids = load_test_vector(adrf_dataset_list,true_links, true_not_links)


    calibration_metrics = dict()
    max_f1_score = 0
    selected_lsh_threshold = 0
    for step in range(80, 100, 1):

        lsh_threshold = step/ 100
        print(lsh_threshold)

        result = run_model(adrf_dataset_list, rc_corpus, lsh_threshold,classified_ids)

        scores = get_confusion_matrix_scores(test_vector, result)

        print('confusion matrix for ' + str(lsh_threshold))
        # print("\tTP: " + str(tp) + "\tFP: " + str(fp))
        # print("\tFN: " + str(fn) + "\tTN: " + str(tn))
        pprint(scores["confusion_matrix"])

        calibration_metrics[lsh_threshold] = scores

        if scores["f1_score"] > max_f1_score:
            selected_lsh_threshold = lsh_threshold
            max_f1_score = scores["f1_score"]

    print("\nshowing all metrics...")
    pprint(calibration_metrics)
    print("Selected threshold:",selected_lsh_threshold)
    pprint(calibration_metrics[selected_lsh_threshold])





if __name__ == '__main__':

    #Enforcing only 2 parameters.
    # if(len(sys.argv[1:]) != 2):
    #     print("Only 2 parameters allowed")
    #     exit(1)
    # corpus_path = sys.argv[1]
    # search_for_matches_path = sys.argv[2]


    corpus_path= "copy_datasets.json"
    search_for_matches_path = "adrf_data/datasets-02-11-2020.json"

    main(corpus_path,search_for_matches_path)

# %%
import re
import sys
import codecs
import json
import fuzzywuzzy
from collections import defaultdict
from difflib import SequenceMatcher
from fuzzywuzzy import fuzz
from datasketch import MinHashLSHEnsemble, MinHash
from sklearn import metrics

#added packages to work on automating record linakges with github files
import requests
import urllib

# %%
search_for_matches_path = "/Users/andrewnorris/RichContextMetadata/metadata/BBK_corpus.0_1_5/adrf_data/datasets-02-11-2020.json"
with codecs.open(search_for_matches_path, "r", encoding="utf8") as f:
    adrf_dataset_list = json.load(f)

# %%
adrf_dataset_list[:1]
# Out:
# [{'model': 'ds.dataset',
#   'pk': 1,
#   'fields': {'temporal_coverage_start': '1990',
#    'temporal_coverage_end': '2015',
#    'files_total': 1,
#    'data_classification': 'Restricted',
#    'access_actions_required': 'This is ADRF course data. In order to access, you must have signed the appropriate NDA and agreed to the ADRF terms of usage. These data are located in the course database. Field specific metadata are a sample only.',
#    'geographical_coverage': '["Illinois"]',
#    'dataset_id': 'adrf-000001',
#    'category': 'Inmate Populations',
#    'dataset_version': 1,
#    'title': 'Illinois Department of Corrections (DOC) Inmate Admissions 1990-2015',
#    'data_usage_policy': 'This dataset is restricted to ADRF course participants who have approval and have agreed to the terms of use provided by the Illinois Department of Corrections (IDOC). The user shall not attempt to re-identify individuals represented in the data and agree to not disclose any data contained here to any unauthorized parties. Any analyses and data products derived from the data must be reviewed by IDOC before export from this system.',
#    'data_steward_organization': 'Center for Urban Science and Progress (CUSP), NYU',
#    'data_steward': 80,
#    'files': [{'file_name': 'adrf-000001-ildoc_admit.csv',
#      'columns_metadata': {'id': {'categories': [],
#        'categorical': False,
#        'description': 'Auto-generated Unique ID for ADRF',
#        'provided-type': 'bigint'},
#       'nbr': {'categories': [],
#        'categorical': False,
#        'description': 'Numberic portion of IDOC Number',
#        'provided-type': 'bigint'},
#       'sex': {'categories': [],
#        'categorical': False,
#        'description': 'Sex',
#        'provided-type': 'text'},
#       'anbr': {'categories': [{'label': "Indeterminate admitted in the 70's and opted for determinate.",
#          'value': 'A'},
#         {'label': "Determinate admitted in the 80's.", 'value': 'N'},
#         {'label': "Determinate admitted in the 90's.", 'value': 'B'},
#         {'label': "Indeterminate admitted in the 70's.", 'value': 'C'},
#         {'label': "Indeterminate admitted in the 80's.", 'value': 'L'},
#         {'label': "Indeterminate admitted in the 90's.", 'value': 'H'},
#         {'label': 'Periodic imprisonment.', 'value': 'P'},
#         {'label': 'Determinate admitted in the 2003.', 'value': 'S'},
#         {'label': 'From another state for parole supervision.', 'value': 'X'}],
#        'categorical': True,
#        'description': "Alpha portion of IDOC Number\n\n\nA=Indeterminate admitted in the 70's and opted for determinate.\nN=Determinate admitted in the 80's.\nB=Determinate admitted in the 90's.\nC=Indeterminate admitted in the 70's.\nL=Indeterminate admitted in the 80's.\nH=Indeterminate admitted in the 90's.\nP=Periodic imprisonment.\nS=Determinate admitted in the 2003.\nX=From another state for parole supervision.",
#        'provided-type': 'text'},
#       'gang': {'categories': [],
#        'categorical': False,
#        'description': 'Gang Affiliation',
#        'provided-type': 'text'},
#       'kids': {'categories': [],
#        'categorical': False,
#        'description': 'Number of Children',
#        'provided-type': 'bigint'},
#       'race': {'categories': [],
#        'categorical': False,
#        'description': 'Race',
#        'provided-type': 'text'},
#       'vetf': {'categories': [],
#        'categorical': False,
#        'description': 'Veteran Flag',
#        'provided-type': 'text'},
#       'dnada': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Test Date Day',
#        'provided-type': 'bigint'},
#       'dnadt': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Test Date',
#        'provided-type': 'bigint'},
#       'dnamo': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Test Date Month',
#        'provided-type': 'bigint'},
#       'dnayr': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Test Date Year',
#        'provided-type': 'bigint'},
#       'sntda': {'categories': [],
#        'categorical': False,
#        'description': 'Sentence Date Day',
#        'provided-type': 'bigint'},
#       'sntdt': {'categories': [],
#        'categorical': False,
#        'description': 'Sentence Date',
#        'provided-type': 'bigint'},
#       'sntmo': {'categories': [],
#        'categorical': False,
#        'description': 'Sentence Date Month',
#        'provided-type': 'bigint'},
#       'sntyr': {'categories': [],
#        'categorical': False,
#        'description': 'Sentence Date Year',
#        'provided-type': 'bigint'},
#       'svpda': {'categories': [],
#        'categorical': False,
#        'description': 'SVP Status Day',
#        'provided-type': 'bigint'},
#       'svpmo': {'categories': [],
#        'categorical': False,
#        'description': 'SVP Status Month',
#        'provided-type': 'bigint'},
#       'svpyr': {'categories': [],
#        'categorical': False,
#        'description': 'SVP Status Year',
#        'provided-type': 'bigint'},
#       'tsent': {'categories': [],
#        'categorical': False,
#        'description': 'Indicator Percentage Flag. Where there appear to be duplicates for the same individual, presence of this indicator means it is the most recent record for this dataset.',
#        'provided-type': 'text'},
#       'zipp4': {'categories': [],
#        'categorical': False,
#        'description': 'Zipcode 4-digit suffix',
#        'provided-type': 'double precision'},
#       'custda': {'categories': [],
#        'categorical': False,
#        'description': 'Custody Date Day',
#        'provided-type': 'bigint'},
#       'custdt': {'categories': [],
#        'categorical': False,
#        'description': 'Custody Date',
#        'provided-type': 'bigint'},
#       'custmo': {'categories': [],
#        'categorical': False,
#        'description': 'Custody Date Month',
#        'provided-type': 'bigint'},
#       'custyr': {'categories': [],
#        'categorical': False,
#        'description': 'Custody Date Year',
#        'provided-type': 'bigint'},
#       'dnamsr': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing (outside IDOC)',
#        'provided-type': 'text'},
#       'docnbr': {'categories': [],
#        'categorical': False,
#        'description': 'IDOC Number',
#        'provided-type': 'text'},
#       'ethnic': {'categories': [],
#        'categorical': False,
#        'description': 'Ethnic Preference',
#        'provided-type': 'text'},
#       'hclass': {'categories': [{'label': 'Missing', 'value': '0'},
#         {'label': 'Class 1', 'value': '1'},
#         {'label': 'Class 2', 'value': '2'},
#         {'label': 'Class 3', 'value': '3'},
#         {'label': 'Class 4', 'value': '4'},
#         {'label': 'Class A - Misdemeanor', 'value': 'A'},
#         {'label': 'Class B - Misdemeanor', 'value': 'B'},
#         {'label': 'Class C - Misdemeanor', 'value': 'C'},
#         {'label': 'Murder', 'value': 'M'},
#         {'label': 'Unclassified', 'value': 'U'},
#         {'label': 'Class X Felony', 'value': 'X'}],
#        'categorical': True,
#        'description': 'Holding Crime Class\n\n\n0=Missing\n1=Class 1\n2=Class 2\n3=Class 3\n4=Class 4\nA=Class A - Misdemeanor\nB=Class B - Misdemeanor\nC=Class C - Misdemeanor\nM=Murder\nU=Unclassified\nX=Class X Felony',
#        'provided-type': 'text'},
#       'offcat': {'categories': [{'label': 'No Category', 'value': '0'},
#         {'label': 'Abortion', 'value': '1'},
#         {'label': 'Habitual Offender', 'value': '2'},
#         {'label': 'Inchoate', 'value': '3'},
#         {'label': 'Homicide', 'value': '4'},
#         {'label': 'Kidnapping-Restraining-Abduction', 'value': '5'},
#         {'label': 'Rape-Other Serious Sex Offense Before July 1984',
#          'value': '6'},
#         {'label': 'Sex Related Offense', 'value': '7'},
#         {'label': 'Assault-Battery-Force-Harm', 'value': '8'},
#         {'label': 'Home-Vehicular Invasion', 'value': '9'},
#         {'label': 'Theft', 'value': '10'},
#         {'label': 'Retail Theft', 'value': '11'},
#         {'label': 'Forger-Deception-Fraud', 'value': '12'},
#         {'label': 'Robbery', 'value': '13'},
#         {'label': 'Armed Robbery', 'value': '14'},
#         {'label': 'Burglary', 'value': '15'},
#         {'label': 'Residential Burglary', 'value': '16'},
#         {'label': 'Arson', 'value': '17'},
#         {'label': 'Criminal Trespass-Damage to Property', 'value': '18'},
#         {'label': 'Possession Hypos', 'value': '19'},
#         {'label': 'Weapons', 'value': '20'},
#         {'label': 'Disorderly Conduct-Mob Action', 'value': '21'},
#         {'label': 'Gambling', 'value': '22'},
#         {'label': 'Government-Bribery-Bus Offenses', 'value': '23'},
#         {'label': 'Escape-Aid Escape', 'value': '24'},
#         {'label': 'Bail Bond Violation', 'value': '25'},
#         {'label': 'Armed Violence', 'value': '26'},
#         {'label': 'Cannabis', 'value': '27'},
#         {'label': 'Cont Subs violation', 'value': '28'},
#         {'label': 'Motor Vehicle Offenses', 'value': '29'},
#         {'label': 'Sex Assault-Other Serious Sex Offense After June 1984',
#          'value': '30'},
#         {'label': 'DUI-Liquor', 'value': '31'},
#         {'label': 'Motor Vehicle THemft', 'value': '32'},
#         {'label': 'SDP', 'value': '33'}],
#        'categorical': True,
#        'description': 'Holding OFNS Category\n\n\n0=No Category\n1=Abortion\n2=Habitual Offender\n3=Inchoate\n4=Homicide\n5=Kidnapping-Restraining-Abduction\n6=Rape-Other Serious Sex Offense Before July 1984\n7=Sex Related Offense\n8=Assault-Battery-Force-Harm\n9=Home-Vehicular Invasion\n10=Theft\n11=Retail Theft\n12=Forger-Deception-Fraud\n13=Robbery\n14=Armed Robbery\n15=Burglary\n16=Residential Burglary\n17=Arson\n18=Criminal Trespass-Damage to Property\n19=Possession Hypos\n20=Weapons\n21=Disorderly Conduct-Mob Action\n22=Gambling\n23=Government-Bribery-Bus Offenses\n24=Escape-Aid Escape\n25=Bail Bond Violation\n26=Armed Violence\n27=Cannabis\n28=Cont Subs violation\n29=Motor Vehicle Offenses\n30=Sex Assault-Other Serious Sex Offense After June 1984\n31=DUI-Liquor\n32=Motor Vehicle THemft\n33=SDP',
#        'provided-type': 'bigint'},
#       'seclvl': {'categories': [],
#        'categorical': False,
#        'description': 'Security Level',
#        'provided-type': 'text'},
#       'sexoff': {'categories': [],
#        'categorical': False,
#        'description': 'Sex Offense Flag',
#        'provided-type': 'text'},
#       'snttyp': {'categories': [],
#        'categorical': False,
#        'description': 'Sentence Type',
#        'provided-type': 'bigint'},
#       'admtypo': {'categories': [{'label': 'ADMIT FROM OTHER CUSTODY',
#          'value': 'AOC'},
#         {'label': 'CONDITIONAL RELEASE VIOLATOR', 'value': 'CRV'},
#         {'label': 'CONDITIONAL RLSE VIOL, NEW SEN', 'value': 'CRN'},
#         {'label': 'DIRECT FROM COURT', 'value': 'DFC'},
#         {'label': 'DISCHARGE AND RECOMMITTAL', 'value': 'DR'},
#         {'label': 'DRC', 'value': 'DRC'},
#         {'label': 'ED-CRIMINAL OFFENSE', 'value': 'CRM'},
#         {'label': 'ED-ESCAPE', 'value': 'ESC'},
#         {'label': 'ED-UNAUTHORIZED ABSENCE/MVMT', 'value': 'ABS'},
#         {'label': 'ELECT DETENTION VIOL/NEW SENT', 'value': 'EDC'},
#         {'label': 'ELECTRONIC DETENTION VIOLATOR', 'value': 'EDV'},
#         {'label': 'FROM OTHER STATE', 'value': 'FOS'},
#         {'label': 'JRC', 'value': 'JRC'},
#         {'label': 'JUV PAROLE TO ADULT PAROLE', 'value': 'JAP'},
#         {'label': 'MSR VIOLATOR, NEW SENTENCE', 'value': 'MVN'},
#         {'label': 'N/A', 'value': 'N/A'},
#         {'label': 'NOT IDOC CUSTODY', 'value': 'NIC'},
#         {'label': 'PAROLE VIOLATOR, NEW SENTENCE', 'value': 'PVN'},
#         {'label': 'PERIODIC IMPRISONMENT', 'value': 'PI'},
#         {'label': 'RETURN ADDITIONAL MITT', 'value': 'RAM'},
#         {'label': 'RETURN TO CUSTODY', 'value': 'RTC'},
#         {'label': 'TECHNICAL MSR VIOLATOR', 'value': 'TMV'},
#         {'label': 'TECHNICAL PAROLE VIOLATOR', 'value': 'TPV'},
#         {'label': 'TRANSFERRED FROM JUVENILE', 'value': 'TRJ'},
#         {'label': 'WD-MISCELLANEOUS RULE VIOLATION', 'value': 'MSC'},
#         {'label': 'WORK RELEASE VIOL., NEW SENT.', 'value': 'WRN'},
#         {'label': 'WORK RELEASE VIOLATOR', 'value': 'WRV'}],
#        'categorical': True,
#        'description': 'Admission Type at Reception. Note: TMV and MVN are Determinate, TPV and PVN are Indeterminate. TMV and TPV violate their parole and are seen by the PRB (Prison Advisory Board) to determine if their supervised release will be revoked, if they will resume supervision or if they will resume supervision after they obtain an approved host site. MVN and PVN have violated their parole by committing a new crime and are given a new sentence by a judge.\n\n\nAOC=ADMIT FROM OTHER CUSTODY\nCRV=CONDITIONAL RELEASE VIOLATOR\nCRN=CONDITIONAL RLSE VIOL, NEW SEN\nDFC=DIRECT FROM COURT\nDR=DISCHARGE AND RECOMMITTAL\nDRC=DRC\nCRM=ED-CRIMINAL OFFENSE\nESC=ED-ESCAPE\nABS=ED-UNAUTHORIZED ABSENCE/MVMT\nEDC=ELECT DETENTION VIOL/NEW SENT\nEDV=ELECTRONIC DETENTION VIOLATOR\nFOS=FROM OTHER STATE\nJRC=JRC\nJAP=JUV PAROLE TO ADULT PAROLE\nMVN=MSR VIOLATOR, NEW SENTENCE\nN/A=N/A\nNIC=NOT IDOC CUSTODY\nPVN=PAROLE VIOLATOR, NEW SENTENCE\nPI=PERIODIC IMPRISONMENT\nRAM=RETURN ADDITIONAL MITT\nRTC=RETURN TO CUSTODY\nTMV=TECHNICAL MSR VIOLATOR\nTPV=TECHNICAL PAROLE VIOLATOR\nTRJ=TRANSFERRED FROM JUVENILE\nMSC=WD-MISCELLANEOUS RULE VIOLATION\nWRN=WORK RELEASE VIOL., NEW SENT.\nWRV=WORK RELEASE VIOLATOR',
#        'provided-type': 'text'},
#       'aoiccde': {'categories': [],
#        'categorical': False,
#        'description': 'AOIC Code',
#        'provided-type': 'text'},
#       'birthda': {'categories': [],
#        'categorical': False,
#        'description': 'Birth Date Day',
#        'provided-type': 'bigint'},
#       'birthdt': {'categories': [],
#        'categorical': False,
#        'description': 'Birth Date Full',
#        'provided-type': 'bigint'},
#       'birthmo': {'categories': [],
#        'categorical': False,
#        'description': 'Birth Date Month',
#        'provided-type': 'bigint'},
#       'birthpl': {'categories': [],
#        'categorical': False,
#        'description': 'Birth Place. See birthpl_state_country_codes.csv for birth place descriptions.',
#        'provided-type': 'text'},
#       'birthyr': {'categories': [],
#        'categorical': False,
#        'description': 'Birth Date Year',
#        'provided-type': 'bigint'},
#       'citzshp': {'categories': [{'label': 'Native Born', 'value': '1'},
#         {'label': 'Naturalized Citizen', 'value': '2'},
#         {'label': 'Alien', 'value': '3'},
#         {'label': 'Foriegn National', 'value': '4'},
#         {'label': 'Resident Alien', 'value': '5'},
#         {'label': 'Alien EWI', 'value': '6'},
#         {'label': 'Alien NI', 'value': '7'},
#         {'label': 'Alien MAR', 'value': '8'}],
#        'categorical': True,
#        'description': 'Citizenship\n\n\n1=Native Born\n2=Naturalized Citizen\n3=Alien\n4=Foriegn National\n5=Resident Alien\n6=Alien EWI\n7=Alien NI\n8=Alien MAR',
#        'provided-type': 'text'},
#       'comcnty': {'categories': [],
#        'categorical': False,
#        'description': 'Committing County',
#        'provided-type': 'bigint'},
#       'cscalc1': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 1 Truth in Sentencing',
#        'provided-type': 'text'},
#       'cscalc2': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 2 Truth in Sentencing',
#        'provided-type': 'text'},
#       'cscalc3': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 3 Truth in Sentencing',
#        'provided-type': 'double precision'},
#       'cscalc4': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 4 Truth in Sentencing',
#        'provided-type': 'double precision'},
#       'cscalc5': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 5 Truth in Sentencing',
#        'provided-type': 'double precision'},
#       'cssntdd': {'categories': [],
#        'categorical': False,
#        'description': 'Total Sentence: c) days',
#        'provided-type': 'double precision'},
#       'cssntmm': {'categories': [],
#        'categorical': False,
#        'description': 'Total Sentence: b) months',
#        'provided-type': 'text'},
#       'cssntyy': {'categories': [],
#        'categorical': False,
#        'description': 'Total Sentence: a) years',
#        'provided-type': 'text'},
#       'distloc': {'categories': [],
#        'categorical': False,
#        'description': 'Location District',
#        'provided-type': 'double precision'},
#       'dnainst': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing (inside IDOC)',
#        'provided-type': 'text'},
#       'dnatest': {'categories': [],
#        'categorical': False,
#        'description': 'Individual DNA tested',
#        'provided-type': 'text'},
#       'educlvl': {'categories': [{'label': 'Missing', 'value': '0'},
#         {'label': 'Some Grade School', 'value': '1'},
#         {'label': 'Grade School Graduate', 'value': '2'},
#         {'label': 'Some High School', 'value': '3'},
#         {'label': 'High School Graduate', 'value': '4'},
#         {'label': 'Some College', 'value': '5'},
#         {'label': 'College Graduate', 'value': '6'},
#         {'label': 'Advanced Degree', 'value': '7'},
#         {'label': 'GED', 'value': '8'},
#         {'label': 'Unknown', 'value': '9'},
#         {'label': 'Technical School', 'value': '10'}],
#        'categorical': True,
#        'description': 'Education Level\n\n\n0=Missing\n1=Some Grade School\n2=Grade School Graduate\n3=Some High School\n4=High School Graduate\n5=Some College\n6=College Graduate\n7=Advanced Degree\n8=GED\n9=Unknown\n10=Technical School',
#        'provided-type': 'text'},
#       'escrisk': {'categories': [],
#        'categorical': False,
#        'description': 'Escape Risk',
#        'provided-type': 'text'},
#       'gangact': {'categories': [],
#        'categorical': False,
#        'description': 'Gang member (Active/Inactive)',
#        'provided-type': 'text'},
#       'gangpos': {'categories': [],
#        'categorical': False,
#        'description': 'Gang Position',
#        'provided-type': 'text'},
#       'gttyp01': {'categories': [],
#        'categorical': False,
#        'description': 'Meritorious Good Time',
#        'provided-type': 'bigint'},
#       'gttyp02': {'categories': [],
#        'categorical': False,
#        'description': 'Bond Lost Time',
#        'provided-type': 'bigint'},
#       'gttyp03': {'categories': [],
#        'categorical': False,
#        'description': 'Escape Lost Time',
#        'provided-type': 'bigint'},
#       'gttyp04': {'categories': [],
#        'categorical': False,
#        'description': 'Probation Credit',
#        'provided-type': 'bigint'},
#       'gttyp05': {'categories': [],
#        'categorical': False,
#        'description': 'Good Conduct Credit Restored',
#        'provided-type': 'bigint'},
#       'gttyp06': {'categories': [],
#        'categorical': False,
#        'description': 'statutory good conduct credits (previously revoked) in days restored',
#        'provided-type': 'bigint'},
#       'gttyp07': {'categories': [],
#        'categorical': False,
#        'description': 'Parole Violation Lost Time',
#        'provided-type': 'bigint'},
#       'gttyp08': {'categories': [],
#        'categorical': False,
#        'description': 'MSR violation Lost Time',
#        'provided-type': 'bigint'},
#       'gttyp09': {'categories': [],
#        'categorical': False,
#        'description': 'Institutional Credits',
#        'provided-type': 'bigint'},
#       'gttyp10': {'categories': [],
#        'categorical': False,
#        'description': 'AATime - Initial load (lost)',
#        'provided-type': 'bigint'},
#       'gttyp11': {'categories': [],
#        'categorical': False,
#        'description': 'Good Conduct Credit Revoked',
#        'provided-type': 'bigint'},
#       'gttyp12': {'categories': [],
#        'categorical': False,
#        'description': 'Statutory Good Time Revoked',
#        'provided-type': 'bigint'},
#       'gttyp13': {'categories': [],
#        'categorical': False,
#        'description': 'AATime Initial load (time granted)',
#        'provided-type': 'bigint'},
#       'gttyp14': {'categories': [],
#        'categorical': False,
#        'description': 'Good Conduct Credit Earned',
#        'provided-type': 'bigint'},
#       'gttyp15': {'categories': [],
#        'categorical': False,
#        'description': 'Supplemental Meritorious Good Time Credit',
#        'provided-type': 'bigint'},
#       'gttyp16': {'categories': [],
#        'categorical': False,
#        'description': 'Educational Good Time Credit',
#        'provided-type': 'bigint'},
#       'gttyp17': {'categories': [],
#        'categorical': False,
#        'description': 'Earned Time Education',
#        'provided-type': 'bigint'},
#       'gttyp18': {'categories': [],
#        'categorical': False,
#        'description': 'Earned Time Substance Abuse',
#        'provided-type': 'bigint'},
#       'gttyp19': {'categories': [],
#        'categorical': False,
#        'description': 'Earned Time Industry',
#        'provided-type': 'bigint'},
#       'hofnscd': {'categories': [],
#        'categorical': False,
#        'description': 'Holding Crime SPSS Code. See SPSS codes in Offenses_and_SPSS_codes.csv',
#        'provided-type': 'bigint'},
#       'ilincar': {'categories': [],
#        'categorical': False,
#        'description': 'Number Illinois Incarceration',
#        'provided-type': 'bigint'},
#       'iqscore': {'categories': [],
#        'categorical': False,
#        'description': 'IQ Score',
#        'provided-type': 'text'},
#       'ispvlvl': {'categories': [],
#        'categorical': False,
#        'description': 'Supervision Level',
#        'provided-type': 'text'},
#       'marstat': {'categories': [],
#        'categorical': False,
#        'description': 'Marital Status',
#        'provided-type': 'text'},
#       'mnsntdd': {'categories': [],
#        'categorical': False,
#        'description': 'Minimum Sentence: c) days',
#        'provided-type': 'double precision'},
#       'mnsntmm': {'categories': [],
#        'categorical': False,
#        'description': 'Minimum Sentence: b) months',
#        'provided-type': 'text'},
#       'mnsntyy': {'categories': [],
#        'categorical': False,
#        'description': 'Minimum Sentence: a) years',
#        'provided-type': 'text'},
#       'mxsntdd': {'categories': [],
#        'categorical': False,
#        'description': 'Maximum Sentence: c) days',
#        'provided-type': 'double precision'},
#       'mxsntmm': {'categories': [],
#        'categorical': False,
#        'description': 'Maximum Sentence: b) months',
#        'provided-type': 'text'},
#       'mxsntyy': {'categories': [],
#        'categorical': False,
#        'description': 'Maximum Sentence: a) years',
#        'provided-type': 'text'},
#       'offnsda': {'categories': [],
#        'categorical': False,
#        'description': 'Offense Day',
#        'provided-type': 'bigint'},
#       'offnsdt': {'categories': [],
#        'categorical': False,
#        'description': 'Offense Date',
#        'provided-type': 'bigint'},
#       'offnsmo': {'categories': [],
#        'categorical': False,
#        'description': 'Offense Month',
#        'provided-type': 'bigint'},
#       'offnsyr': {'categories': [],
#        'categorical': False,
#        'description': 'Offense Year',
#        'provided-type': 'bigint'},
#       'otincar': {'categories': [],
#        'categorical': False,
#        'description': 'Number Other Incarceration',
#        'provided-type': 'bigint'},
#       'secinst': {'categories': [],
#        'categorical': False,
#        'description': 'Institution Security',
#        'provided-type': 'double precision'},
#       'sexpred': {'categories': [],
#        'categorical': False,
#        'description': 'Behavior  Code',
#        'provided-type': 'text'},
#       'sexregh': {'categories': [],
#        'categorical': False,
#        'description': 'Sex Offense-Current or History',
#        'provided-type': 'text'},
#       'sexregn': {'categories': [],
#        'categorical': False,
#        'description': 'Sex Registry Code',
#        'provided-type': 'text'},
#       'svpdate': {'categories': [],
#        'categorical': False,
#        'description': 'SVP Status Date',
#        'provided-type': 'bigint'},
#       'svpstat': {'categories': [],
#        'categorical': False,
#        'description': 'SVP Status',
#        'provided-type': 'text'},
#       'tabe1da': {'categories': [],
#        'categorical': False,
#        'description': 'Day of 1st TABE Test after Admission',
#        'provided-type': 'bigint'},
#       'tabe1dt': {'categories': [],
#        'categorical': False,
#        'description': 'Date of 1st TABE Test after Admission',
#        'provided-type': 'bigint'},
#       'tabe1mo': {'categories': [],
#        'categorical': False,
#        'description': 'Month of 1st TABE Test after Admission',
#        'provided-type': 'bigint'},
#       'tabe1yr': {'categories': [],
#        'categorical': False,
#        'description': 'Year of 1st TABE Test after Admission',
#        'provided-type': 'bigint'},
#       'tabe2da': {'categories': [],
#        'categorical': False,
#        'description': 'Day of Last TABE Test',
#        'provided-type': 'bigint'},
#       'tabe2dt': {'categories': [],
#        'categorical': False,
#        'description': 'Date of Last TABE Test',
#        'provided-type': 'bigint'},
#       'tabe2mo': {'categories': [],
#        'categorical': False,
#        'description': 'Month of Last TABE Test',
#        'provided-type': 'bigint'},
#       'tabe2yr': {'categories': [],
#        'categorical': False,
#        'description': 'Year of Last TABE Test',
#        'provided-type': 'bigint'},
#       'unrilin': {'categories': [],
#        'categorical': False,
#        'description': 'Number Unrecor Illinois Incarceration',
#        'provided-type': 'bigint'},
#       'unrotin': {'categories': [],
#        'categorical': False,
#        'description': 'Number Unrec Other Incarceration',
#        'provided-type': 'bigint'},
#       'wartyp1': {'categories': [],
#        'categorical': False,
#        'description': 'Warrant Type',
#        'provided-type': 'text'},
#       'wartyp2': {'categories': [],
#        'categorical': False,
#        'description': 'Warrant Type',
#        'provided-type': 'text'},
#       'wartyp3': {'categories': [],
#        'categorical': False,
#        'description': 'Warrant Type',
#        'provided-type': 'text'},
#       'wartyp4': {'categories': [],
#        'categorical': False,
#        'description': 'Executed Warrant Type 1',
#        'provided-type': 'text'},
#       'wartyp5': {'categories': [],
#        'categorical': False,
#        'description': 'Executed Warrant Type 2',
#        'provided-type': 'text'},
#       'wartyp6': {'categories': [],
#        'categorical': False,
#        'description': 'Executed Warrant Type 3',
#        'provided-type': 'text'},
#       'weapoff': {'categories': [],
#        'categorical': False,
#        'description': 'Weapons Offense-Current or History',
#        'provided-type': 'text'},
#       'zipcode': {'categories': [],
#        'categorical': False,
#        'description': 'Zipcode',
#        'provided-type': 'text'},
#       'crtfind1': {'categories': [],
#        'categorical': False,
#        'description': 'Court Finding',
#        'provided-type': 'text'},
#       'crtfind2': {'categories': [],
#        'categorical': False,
#        'description': 'Court Finding',
#        'provided-type': 'text'},
#       'crtfind3': {'categories': [],
#        'categorical': False,
#        'description': 'Court Finding',
#        'provided-type': 'text'},
#       'csclass1': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 1 Class',
#        'provided-type': 'text'},
#       'csclass2': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 2 Class',
#        'provided-type': 'text'},
#       'csclass3': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 3 Class',
#        'provided-type': 'text'},
#       'csclass4': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 4 Class',
#        'provided-type': 'text'},
#       'csclass5': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 5 Class',
#        'provided-type': 'text'},
#       'csoffcd1': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 1 Offense',
#        'provided-type': 'bigint'},
#       'csoffcd2': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 2 Offense',
#        'provided-type': 'bigint'},
#       'csoffcd3': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 3 Offense',
#        'provided-type': 'bigint'},
#       'csoffcd4': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 4 Offense',
#        'provided-type': 'bigint'},
#       'csoffcd5': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 5 Offense',
#        'provided-type': 'bigint'},
#       'cssntdd1': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 1 days',
#        'provided-type': 'double precision'},
#       'cssntdd2': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 2 days',
#        'provided-type': 'double precision'},
#       'cssntdd3': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 3 days',
#        'provided-type': 'double precision'},
#       'cssntdd4': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 4 days',
#        'provided-type': 'double precision'},
#       'cssntdd5': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 5 days',
#        'provided-type': 'double precision'},
#       'cssntmm1': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 1 months',
#        'provided-type': 'double precision'},
#       'cssntmm2': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 2 months',
#        'provided-type': 'double precision'},
#       'cssntmm3': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 3 months',
#        'provided-type': 'double precision'},
#       'cssntmm4': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 4 months',
#        'provided-type': 'double precision'},
#       'cssntmm5': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 5 months',
#        'provided-type': 'double precision'},
#       'cssntyy1': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 1 years',
#        'provided-type': 'text'},
#       'cssntyy2': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 2 years',
#        'provided-type': 'text'},
#       'cssntyy3': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 3 years',
#        'provided-type': 'text'},
#       'cssntyy4': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 4 years',
#        'provided-type': 'text'},
#       'cssntyy5': {'categories': [],
#        'categorical': False,
#        'description': 'Consecutive sentence 5 years',
#        'provided-type': 'double precision'},
#       'curadmda': {'categories': [],
#        'categorical': False,
#        'description': 'Current Admission Date - day',
#        'provided-type': 'bigint'},
#       'curadmdt': {'categories': [],
#        'categorical': False,
#        'description': 'Current Admission Date',
#        'provided-type': 'bigint'},
#       'curadmmo': {'categories': [],
#        'categorical': False,
#        'description': 'Current Admission Date - month',
#        'provided-type': 'bigint'},
#       'curadmyr': {'categories': [],
#        'categorical': False,
#        'description': 'Current Admission Date - year',
#        'provided-type': 'bigint'},
#       'dateover': {'categories': [],
#        'categorical': False,
#        'description': 'Dateover Reason to Adjust Release Date',
#        'provided-type': 'text'},
#       'dna_date': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Test Date (Date data type formatted)',
#        'provided-type': 'date'},
#       'dnainsda': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing inside IDOC Day',
#        'provided-type': 'bigint'},
#       'dnainsdt': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing inside IDOC',
#        'provided-type': 'bigint'},
#       'dnainsmo': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing inside IDOC Month',
#        'provided-type': 'bigint'},
#       'dnainsyr': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing inside IDOC Year',
#        'provided-type': 'bigint'},
#       'dnamsrda': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing Outside IDOC Day',
#        'provided-type': 'bigint'},
#       'dnamsrdt': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing Outside IDOC',
#        'provided-type': 'bigint'},
#       'dnamsrmo': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing Outside IDOC Month',
#        'provided-type': 'bigint'},
#       'dnamsryr': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing Outside IDOC Year',
#        'provided-type': 'bigint'},
#       'drugalcf': {'categories': [],
#        'categorical': False,
#        'description': 'Alcohol Flag',
#        'provided-type': 'text'},
#       'drugampf': {'categories': [],
#        'categorical': False,
#        'description': 'Amphetamine Flag',
#        'provided-type': 'text'},
#       'drugcocf': {'categories': [],
#        'categorical': False,
#        'description': 'Cocaine Flag',
#        'provided-type': 'text'},
#       'drugherf': {'categories': [],
#        'categorical': False,
#        'description': 'Heroin Flag',
#        'provided-type': 'text'},
#       'drugmarf': {'categories': [],
#        'categorical': False,
#        'description': 'Marijuana Flag',
#        'provided-type': 'text'},
#       'drugothf': {'categories': [],
#        'categorical': False,
#        'description': 'Other Drug Flag',
#        'provided-type': 'text'},
#       'drugpcpf': {'categories': [],
#        'categorical': False,
#        'description': 'PCP Flag',
#        'provided-type': 'text'},
#       'drugunkf': {'categories': [],
#        'categorical': False,
#        'description': 'Unknown Drug Flag',
#        'provided-type': 'text'},
#       'inchoate': {'categories': [],
#        'categorical': False,
#        'description': 'Inchoate',
#        'provided-type': 'text'},
#       'jailtime': {'categories': [],
#        'categorical': False,
#        'description': 'Total Jail Time',
#        'provided-type': 'bigint'},
#       'parolext': {'categories': [],
#        'categorical': False,
#        'description': 'Extended or Enhanced Parole',
#        'provided-type': 'bigint'},
#       'pendcrim': {'categories': [],
#        'categorical': False,
#        'description': 'Pending Criminal Charges',
#        'provided-type': 'text'},
#       'pendpros': {'categories': [],
#        'categorical': False,
#        'description': 'Pending Prosecution',
#        'provided-type': 'text'},
#       'prjdisda': {'categories': [],
#        'categorical': False,
#        'description': 'Projected Discharge Day',
#        'provided-type': 'bigint'},
#       'prjdisdt': {'categories': [],
#        'categorical': False,
#        'description': 'Projected Discharge',
#        'provided-type': 'bigint'},
#       'prjdismo': {'categories': [],
#        'categorical': False,
#        'description': 'Projected Discharge Month',
#        'provided-type': 'bigint'},
#       'prjdisyr': {'categories': [],
#        'categorical': False,
#        'description': 'Projected Discharge Year',
#        'provided-type': 'bigint'},
#       'prjmsrda': {'categories': [],
#        'categorical': False,
#        'description': 'Projected Release Date Day',
#        'provided-type': 'bigint'},
#       'prjmsrdt': {'categories': [],
#        'categorical': False,
#        'description': 'Projected Release Date',
#        'provided-type': 'bigint'},
#       'prjmsrmo': {'categories': [],
#        'categorical': False,
#        'description': 'Projected Release Date Month',
#        'provided-type': 'bigint'},
#       'prjmsryr': {'categories': [],
#        'categorical': False,
#        'description': 'Projected Release Date Year',
#        'provided-type': 'bigint'},
#       'recpcntr': {'categories': [],
#        'categorical': False,
#        'description': 'Reception Center',
#        'provided-type': 'text'},
#       'religion': {'categories': [],
#        'categorical': False,
#        'description': 'Religion',
#        'provided-type': 'text'},
#       'rlsestat': {'categories': [],
#        'categorical': False,
#        'description': 'Release Status',
#        'provided-type': 'text'},
#       'seceffda': {'categories': [],
#        'categorical': False,
#        'description': 'Security Level Effective Day',
#        'provided-type': 'bigint'},
#       'seceffdt': {'categories': [],
#        'categorical': False,
#        'description': 'Security Level Effective Date',
#        'provided-type': 'bigint'},
#       'seceffmo': {'categories': [],
#        'categorical': False,
#        'description': 'Security Level Effective Month',
#        'provided-type': 'bigint'},
#       'seceffyr': {'categories': [],
#        'categorical': False,
#        'description': 'Security Level Effective Year',
#        'provided-type': 'bigint'},
#       'snt_date': {'categories': [],
#        'categorical': False,
#        'description': 'Sentence Date (Date data type formatted)',
#        'provided-type': 'date'},
#       'ssn_hash': {'categories': [],
#        'categorical': False,
#        'description': 'Hash of Social Security Number',
#        'provided-type': 'text'},
#       'svp_date': {'categories': [],
#        'categorical': False,
#        'description': 'SVP Status Date (Date data type formatted)',
#        'provided-type': 'date'},
#       'sxpredst': {'categories': [],
#        'categorical': False,
#        'description': 'Behavior Status',
#        'provided-type': 'text'},
#       'tabe1frm': {'categories': [],
#        'categorical': False,
#        'description': 'Form used for 1st TABE Test',
#        'provided-type': 'text'},
#       'tabe1mth': {'categories': [],
#        'categorical': False,
#        'description': '1st TABE Math Score',
#        'provided-type': 'bigint'},
#       'tabe1ntk': {'categories': [],
#        'categorical': False,
#        'description': '1st TABE at Intake Flag',
#        'provided-type': 'text'},
#       'tabe1rdg': {'categories': [],
#        'categorical': False,
#        'description': '1st TABE Reading Score',
#        'provided-type': 'bigint'},
#       'tabe2frm': {'categories': [],
#        'categorical': False,
#        'description': 'Form used for Last TABE Test',
#        'provided-type': 'text'},
#       'tabe2mth': {'categories': [],
#        'categorical': False,
#        'description': 'Last TABE Math Score',
#        'provided-type': 'bigint'},
#       'tabe2ntk': {'categories': [],
#        'categorical': False,
#        'description': 'Last TABE at Intake Flag',
#        'provided-type': 'text'},
#       'tabe2rdg': {'categories': [],
#        'categorical': False,
#        'description': 'Last TABE Reading Score',
#        'provided-type': 'bigint'},
#       'victim12': {'categories': [],
#        'categorical': False,
#        'description': 'Victim under 12',
#        'provided-type': 'text'},
#       'victim18': {'categories': [],
#        'categorical': False,
#        'description': 'Victim under 18',
#        'provided-type': 'text'},
#       'victimpa': {'categories': [],
#        'categorical': False,
#        'description': 'Victim Child of Parent Offender',
#        'provided-type': 'text'},
#       'violstat': {'categories': [],
#        'categorical': False,
#        'description': 'Violation Status',
#        'provided-type': 'text'},
#       'warpref4': {'categories': [],
#        'categorical': False,
#        'description': 'Executed Warrant Prefix 1',
#        'provided-type': 'text'},
#       'warpref5': {'categories': [],
#        'categorical': False,
#        'description': 'Executed Warrant Prefix 2',
#        'provided-type': 'text'},
#       'warpref6': {'categories': [],
#        'categorical': False,
#        'description': 'Executed Warrant Prefix 3',
#        'provided-type': 'text'},
#       'cust_date': {'categories': [],
#        'categorical': False,
#        'description': 'Custody Date (Date data type formatted)',
#        'provided-type': 'date'},
#       'person_id': {'categories': [],
#        'categorical': False,
#        'description': 'Foreign Key into person table',
#        'provided-type': 'bigint'},
#       'tabe1mths': {'categories': [],
#        'categorical': False,
#        'description': 'Test of Adult Basic Education - 1st Math Score',
#        'provided-type': 'double precision'},
#       'tabe1rdgs': {'categories': [],
#        'categorical': False,
#        'description': 'Test of Adult Basic Education - 1st Reading Score',
#        'provided-type': 'double precision'},
#       'tabe2mths': {'categories': [],
#        'categorical': False,
#        'description': 'Test of Adult Basic Education - Last Math Score',
#        'provided-type': 'double precision'},
#       'tabe2rdgs': {'categories': [],
#        'categorical': False,
#        'description': 'Test of Adult Basic Education - Last Reading Score',
#        'provided-type': 'double precision'},
#       'birth_date': {'categories': [],
#        'categorical': False,
#        'description': 'Birth Date Full (Date data type formatted)',
#        'provided-type': 'date'},
#       'birth_year': {'categories': [],
#        'categorical': False,
#        'description': 'Integer birth year, from birthyr.',
#        'provided-type': 'integer'},
#       'offns_date': {'categories': [],
#        'categorical': False,
#        'description': 'Offense Date (Date data type formatted)',
#        'provided-type': 'date'},
#       'tabe1_date': {'categories': [],
#        'categorical': False,
#        'description': 'Date of 1st TABE Test after Admission (Date data type formatted)',
#        'provided-type': 'date'},
#       'tabe2_date': {'categories': [],
#        'categorical': False,
#        'description': 'Date of Last TABE Test (Date data type formatted)',
#        'provided-type': 'date'},
#       'curadm_date': {'categories': [],
#        'categorical': False,
#        'description': 'Current Admission Date (Date data type formatted)',
#        'provided-type': 'date'},
#       'dnains_date': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing inside IDOC (Date data type formatted)',
#        'provided-type': 'date'},
#       'dnamsr_date': {'categories': [],
#        'categorical': False,
#        'description': 'DNA Testing Outside IDOC (Date data type formatted)',
#        'provided-type': 'date'},
#       'prjdis_date': {'categories': [],
#        'categorical': False,
#        'description': 'Projected Discharge Date (Date data type formatted)',
#        'provided-type': 'date'},
#       'prjmsr_date': {'categories': [],
#        'categorical': False,
#        'description': 'Projected Release Date (Date data type formatted)',
#        'provided-type': 'date'},
#       'seceff_date': {'categories': [],
#        'categorical': False,
#        'description': 'Security Level Effective Date (Date data type formatted)',
#        'provided-type': 'date'},
#       'name_last_hash': {'categories': [],
#        'categorical': False,
#        'description': 'Hash of Last Name',
#        'provided-type': 'text'},
#       'name_first_hash': {'categories': [],
#        'categorical': False,
#        'description': 'Hash of First Name',
#        'provided-type': 'text'},
#       'name_middle_hash': {'categories': [],
#        'categorical': False,
#        'description': 'Hash of Middle Name',
#        'provided-type': 'text'}}}],
#    'access_requirements': 'You must be enrolled in an ADRF class to access these data.',
#    'description': 'Detailed transactional data of each time a person was admitted to an Illinois Department of Corrections (DOC) facility from 1990 to 2015. Variables include demographic, charges, sentencing, conduct, security level, health and mental health status, gang affiliation. Data are collected using correctional facility data and court records. See data dictionary documentation for detailed description of all fields.\n\n\nPlease access the full dataset in course database table: ildoc.ildoc_admit',
#    'source_url': '',
#    'geographical_unit': '["State", "Zip Code"]',
#    'related_articles': '["rc-000001", "rc-000003", "rc-000005", "rc-000009", "rc-000010"]',
#    'data_provider': 3,
#    'dataset_documentation': '["idoc_admissions_data_dictionary.pdf", "Notes_on_HCLASS_and_EDUCLVL.pdf", "Offenses_and_SPSS_codes.csv", "Offenses_and_SPSS_codes_dd.csv", "birthpl_state_country_codes.csv"]',
#    'dataset_version_date': 1512425531,
#    'source_archive': '',
#    'dataset_citation': 'Illinois Department of Corrections, 2016, "Illinois Department of Corrections (DOC) Inmate Admissions 1990-2015", Applied Data Analytics Course [Distributor], 1 [Version]',
#    'reference_url': 'https://www.illinois.gov/idoc/Pages/default.aspx',
#    'file_names': '["adrf-000001-ildoc_admit.csv"]',
#    'in_adrf': True,
#    'nomination': None,
#    'created_at': '2019-04-04T14:41:26Z',
#    'updated_at': '2019-10-16T15:19:39.425Z',
#    'keywords': [8, 18, 19, 20, 21, 22, 23, 24],
#    'user_that_bookmarked': [1]}}]

# %%
url="https://github.com/NYU-CI/RCCustomers/blob/5e71284c893f39e670a474ec9b7110ec04593e09/customers/USDA/bin/usda_datadump.json"
r = requests.get(url)
adrf_json_data = r.json()

for k in adrf_json_data.keys():
    print(k + ': ', adrf_json_data[k])

# content = json.loads(r.content)
# for i in range(len(content)):
#     print(content[i]['title'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-7-7728bd451080> in <module>
#       1 url="https://github.com/NYU-CI/RCCustomers/blob/5e71284c893f39e670a474ec9b7110ec04593e09/customers/USDA/bin/usda_datadump.json"
#       2 r = requests.get(url)
# ----> 3 adrf_json_data = r.json()
#       4
#       5 for k in adrf_json_data.keys():
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/opt/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 7 column 1 (char 6)

# %%
KNOWN = 1
UNKNOWN = 0

# %%
# 
def title_match(title1, title2):
    pass

# %%
# replaces non-alphanumeric characters with space; converts to lowercase; parses each word 

# Q: what is text input?  list of titles?
def get_set_of_words(text):
    return re.sub("[\W+]", " ", text).lower().split()

# %%
#  
def run_model(adrf_dataset_list, rc_corpus, lsh_threshold, classified_ids,debug=False):

    print("creating MinHashLSHEnsemble with threshold=%s, num_perm=128, num_part=16..." % lsh_threshold)
    # Create an LSH Ensemble index with threshold and number of partition settings.
    lshensemble = MinHashLSHEnsemble(threshold=lsh_threshold, num_perm=128, num_part=16)

    print("indexing all RC dataset's MinHash...")
    # Index takes an iterable of (key, minhash, size)
    lshensemble.index([(key, values["min_hash"], len(values["words"])) for key, values in rc_corpus.items()])

    # test by querying the LSH Ensemble with each ADRF dataset title to explore potential matches
    results = list()
    for adrf_dataset in adrf_dataset_list:
        if adrf_dataset["fields"]["dataset_id"] not in classified_ids:
            continue
        set1 = get_set_of_words(adrf_dataset["fields"]["title"])
        m1 = MinHash(num_perm=128)
        for term in set1:
            m1.update(term.encode("utf8"))

        #print("\nquery for '%s' yields datasets" % adrf_dataset["fields"]["title"])
        matches = False
        for key in lshensemble.query(m1, len(set1)):
            #print(key, rc_corpus[key]["title"])
            matches = True
        if matches:
            results.append(KNOWN)
        else:
            results.append(UNKNOWN)
            #print("no matches")

    return results

# %%
def create_test_vector(rc_dataset_list, adrf_dataset_list):

    true_links = set()
    true_not_links = set()

    for adrf_dataset in adrf_dataset_list:
        print(adrf_dataset)
        title = adrf_dataset["fields"]["title"]
        url = adrf_dataset["fields"]["source_url"]
        adrf_id = adrf_dataset["fields"]["dataset_id"]

        # Excluding by provider (manual search) ## TODO: subject to change!
        # Q: where do these data_providers originate from? how do we know these are invalid?
        # A: from adrf providers json, from names of providers, for each look manyally into RC providers; 
        # if provider not in RC, added here -- these providers 
        if adrf_dataset["fields"]["data_provider"] in [6,7,12,14,17,48]:  #will be more -- automate  
            true_not_links.add(adrf_id)
            continue

            
        url="https://github.com/NYU-CI/RCCustomers/blob/5e71284c893f39e670a474ec9b7110ec04593e09/customers/USDA/bin/usda_datadump.json"
        request = requests.get(url)
        content = json.loads(request.content)
        for i in range(len(content)):
            print(t[i]['title'])
        
        # TODO: check manually from https://github.com/NYU-CI/RCCustomers/blob/5e71284c893f39e670a474ec9b7110ec04593e09/customers/USDA/bin/usda_datadump.json
        # Correct - this is a complete list of titles from link above
        if title in [
            "Information Resources, Inc. (IRI) Consumer Network household-based scanner data",
            "Information Resources, Inc. (IRI) InfoScan retail-based scanner data",
            "FoodAPS National Household Food Acquisition and Purchase Survey",
            "Supplemental Nutrition Assistance Program (SNAP) Administrative Data"
                    ]:
            true_links.add(adrf_id)
            continue

        for rc_dataset in rc_dataset_list:
            if "adrf_id" in rc_dataset and adrf_id == rc_dataset["adrf_id"]: #improve here?  Q: how to?
                true_links.add(adrf_id)
                continue

            if "title" in rc_dataset and title == rc_dataset["title"]:
                true_links.add(adrf_id)
                continue

            if "url" in rc_dataset and url == rc_dataset["url"]:
                true_links.add(adrf_id)
                continue

            #if rc_dataset["id"] in ["dataset-002","dataset-001"]


    return true_links, true_not_links

# %%
def load_test_vector(adrf_dataset_list,true_links, true_not_links): ## TODO: this is partially built

    vector = list()
    classified = list()
    
    for adrf_dataset in adrf_dataset_list:
        if adrf_dataset["fields"]["dataset_id"] in true_links:
            vector.append(KNOWN)
            classified.append(adrf_dataset["fields"]["dataset_id"])
        elif adrf_dataset["fields"]["dataset_id"] in true_not_links:
            vector.append(UNKNOWN)
            classified.append(adrf_dataset["fields"]["dataset_id"])

    return vector, classified

# %%
def main(corpus_path, search_for_matches_path):

    ## TODO: Create known true matches and known false matches lists
        # TODO: for 4 true links see https://github.com/NYU-CI/RCCustomers/blob/5e71284c893f39e670a474ec9b7110ec04593e09/customers/USDA/bin/usda_datadump.json

        
        

    ## TODO: Loop changing threshold from 0.1 to 0.9
        ## TODO: for each threshold, calculate 'confusion matrix'

        
        
    #Load all dataset adrf_ids and titles from ADRF dump
    with codecs.open(search_for_matches_path, "r", encoding="utf8") as f:
        adrf_dataset_list = json.load(f)

    print("loading ADRF dataset corpus...", type(adrf_dataset_list), len(adrf_dataset_list))

    # Load all dataset ids and titles from dataset.json
        #TODO using a temporal copy instead the most updated version˚
    with codecs.open(corpus_path, "r", encoding="utf8") as f:
        rc_dataset_list = json.load(f)

    print("loading RC dataset corpus...",type(rc_dataset_list),len(rc_dataset_list))

    # create a structure to access title and its set of unique words
    rc_corpus = defaultdict()
    for dataset in rc_dataset_list:
        d = dict()
        d["words"] = get_set_of_words(dataset["title"])
        d["title"] = dataset["title"]
        rc_corpus[dataset["id"]] = d

    # create a MinHash for each dataset title
    print("creating MinHash for each RC dataset...")
    for key,values in rc_corpus.items():
        mh = MinHash(num_perm=128)
        for term in values["words"]:
            mh.update(term.encode("utf8"))
        rc_corpus[key]["min_hash"] = mh

    true_links, true_not_links = create_test_vector(rc_dataset_list, adrf_dataset_list)

    test_vector,classified_ids = load_test_vector(adrf_dataset_list,true_links, true_not_links)

   # for step in range(85, 100, 1): # modify loop for changing thresholds from 0.1 to 0.9 
    for step in range(10,100,10):    # Q:  check at 0.1 increments (rather than 0.01)?
    
        lsh_threshold = step/ 100
        print(lsh_threshold)

        result = run_model(adrf_dataset_list, rc_corpus, lsh_threshold, classified_ids)
        print('confusion matrix for '+str(lsh_threshold)+":\n", metrics.confusion_matrix(test_vector, result) )
        print('accuracy', metrics.accuracy_score(test_vector, result) )
        print('recall', metrics.recall_score(test_vector, result) )
        print('precision', metrics.precision_score(test_vector, result) ) #when you want to minimize false positives use precision.
        print('F-Measure', metrics.f1_score(test_vector, result) )

# %%
if __name__ == '__main__':

    #Enforcing only 2 parameters.
    # if(len(sys.argv[1:]) != 2):
    #     print("Only 2 parameters allowed")
    #     exit(1)
    # corpus_path = sys.argv[1]
    # search_for_matches_path = sys.argv[2]


    corpus_path= "copy_datasets.json"
    search_for_matches_path = "adrf_data/datasets-02-11-2020.json"

    create_test_vector(corpus_path,search_for_matches_path)
# Out:
# a
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-df1ad18e00a7> in <module>
#      12     search_for_matches_path = "adrf_data/datasets-02-11-2020.json"
#      13
# ---> 14     create_test_vector(corpus_path,search_for_matches_path)
#
# <ipython-input-15-7b331b7f6e69> in create_test_vector(rc_dataset_list, adrf_dataset_list)
#       6     for adrf_dataset in adrf_dataset_list:
#       7         print(adrf_dataset)
# ----> 8         title = adrf_dataset["fields"]["title"]
#       9         url = adrf_dataset["fields"]["source_url"]
#      10         adrf_id = adrf_dataset["fields"]["dataset_id"]
#
# TypeError: string indices must be integers
