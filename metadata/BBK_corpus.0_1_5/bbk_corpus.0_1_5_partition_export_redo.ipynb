# %%
import json
import numpy as np
import pandas as pd

# %%
filename = '/Users/andrewnorris/RCHuman/manual/partitions/corpus.0_1_5.json'

# %%
with open(filename, 'r') as f_in:
    data = json.load(f_in)

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [{'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1370/afm.79',
#    'journal': 'journal-371',
#    'pdf': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1466694/pdf/0020351.pdf',
#    'url': 'http://europepmc.org/articles/PMC5353819'},
#   'title': 'Subclinical hypothyroidism and the risk of hypercholesterolemia'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/jnci/djm204',
#    'journal': 'journal-831',
#    'pdf': 'https://pdfs.semanticscholar.org/408b/89db05438a53797bcf9128a3d9a43103065b.pdf',
#    'url': 'https://academic.oup.com/jnci/article/99/21/1594/933627'},
#   'title': 'Prospective study of serum vitamin D and cancer mortality in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1475-2891-4-27',
#    'journal': 'journal-177',
#    'pdf': 'https://nutritionj.biomedcentral.com/track/pdf/10.1186/1475-2891-4-27',
#    'url': 'http://www.nutritionj.com/content/4/1/27'},
#   'title': 'Ethnic variation in validity of classification of overweight and obesity using self-reported weight and height in American women and men: The Third National Health and Nutrition Examination Survey'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2474-12-182',
#    'journal': 'journal-832',
#    'pdf': 'https://bmcmusculoskeletdisord.biomedcentral.com/track/pdf/10.1186/1471-2474-12-182',
#    'url': 'http://www.biomedcentral.com/1471-2474/12/182'},
#   'title': 'Reference ranges for bone mineral density and prevalence of osteoporosis in Vietnamese men and women'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2350-11-6',
#    'journal': 'journal-833',
#    'pdf': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2826307/pdf/1471-2350-11-6.pdf',
#    'url': 'https://doaj.org/toc/1471-2350'},
#   'title': 'Gene polymorphisms in association with emerging cardiovascular risk markers in adult women'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc09-0574',
#    'journal': 'journal-300',
#    'pdf': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2782994/pdf/zdc2297.pdf',
#    'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2782994/'},
#   'title': 'Are metabolically normal but obese individuals at lower risk for all-cause mortality?'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1038/ki.2009.288',
#    'journal': 'journal-834',
#    'pdf': 'https://www.kidney-international.org/article/S0085-2538(15)54099-4/pdf',
#    'url': 'http://dx.doi.org/10.1038/ki.2009.288'},
#   'title': 'Chronic kidney disease, hypovitaminosis D, and mortality in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1038/ki.2010.291',
#    'journal': 'journal-834',
#    'pdf': 'https://www.kidney-international.org/article/S0085-2538(15)54671-1/pdf',
#    'url': 'http://dx.doi.org/10.1038/ki.2010.291'},
#   'title': 'Kidney function and risk triage in adults: Threshold values and hierarchical importance'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2350-11-155',
#    'journal': 'journal-833',
#    'pdf': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2991302/pdf/1471-2350-11-155.pdf',
#    'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2991302/'},
#   'title': 'Inflammation gene variants and susceptibility to albuminuria in the U.S. population: Analysis in the Third National Health and Nutrition Examination Survey (NHANES III), 1991-1994'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1475-2891-6-30',
#    'journal': 'journal-177',
#    'pdf': 'https://nutritionj.biomedcentral.com/track/pdf/10.1186/1475-2891-6-30',
#    'url': 'http://www.nutritionj.com/content/6/1/30'},
#   'title': 'Usage patterns, health, and nutritional status of long-term multiple dietary supplement users: A cross-sectional study'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1155/2012/320482',
#    'journal': 'journal-835',
#    'pdf': 'http://downloads.hindawi.com/journals/ije/2012/320482.pdf',
#    'url': 'http://dx.doi.org/10.1155/2012/320482'},
#   'title': 'Pancreatic function, type 2 diabetes, and metabolism in aging'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1111/apt.12432',
#    'journal': 'journal-836',
#    'pdf': None,
#    'url': 'https://onlinelibrary.wiley.com/doi/full/10.1111/apt.12432'},
#   'title': 'Mortality associated with alcohol-related liver disease'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0015088',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/articles/PMC3001474?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3001474'},
#   'title': 'VKORC1 common variation and bone mineral density in the Third National Health and Nutrition Examination Survey'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0016103',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/articles/PMC3040745?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3040745'},
#   'title': 'Seropositivity to cytomegalovirus, inflammation, all-cause and cardiovascular disease-related mortality in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.3402/fnr.v56i0.5944',
#    'journal': 'journal-837',
#    'pdf': 'http://europepmc.org/articles/PMC3321254?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3321254'},
#   'title': 'Assessing vitamin status in large population surveys by measuring biomarkers and dietary intake - two case studies: Folate and vitamin D'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/s12889-016-3744-z',
#    'journal': 'journal-278',
#    'pdf': 'http://europepmc.org/articles/PMC5075398?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC5075398'},
#   'title': 'Racial disparities in adult all-cause and cause-specific mortality among us adults: mediating and moderating factors'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2458-8-383',
#    'journal': 'journal-278',
#    'pdf': 'http://europepmc.org/articles/PMC2587469?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2587469'},
#   'title': 'The non-linear risk of mortality by income level in a healthy population: US National Health and Nutrition Examination Survey mortality follow-up cohort, 1988–2001'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2334-7-71',
#    'journal': 'journal-838',
#    'pdf': 'http://europepmc.org/articles/PMC1925089?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC1925089'},
#   'title': 'Incidence of cytomegalovirus infection among the general population and pregnant women in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2431-6-12',
#    'journal': 'journal-329',
#    'pdf': 'http://europepmc.org/articles/PMC1459154?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC1459154'},
#   'title': 'Subclinical thyroid disorders and cognitive performance among adolescents in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2458-5-41',
#    'journal': 'journal-278',
#    'pdf': 'http://europepmc.org/articles/PMC1097739?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC1097739'},
#   'title': 'Ethnic and age-related fat free mass loss in older Americans: The Third National Health and Nutrition Examination Survey (NHANES III)'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1476-511X-3-29',
#    'journal': 'journal-024',
#    'pdf': 'http://europepmc.org/articles/PMC544891?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC544891'},
#   'title': 'Correlates of serum lipoprotein (A) in children and adolescents in the United States. The Third National Health Nutrition and Examination Survey (NHANES-III)'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2334-12-86',
#    'journal': 'journal-838',
#    'pdf': 'http://europepmc.org/articles/PMC3342214?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3342214'},
#   'title': 'The burden of hepatitis C in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1476-069X-9-11',
#    'journal': 'journal-839',
#    'pdf': 'http://europepmc.org/articles/PMC2848015?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2848015'},
#   'title': 'Perturbation of lipids and glucose metabolism associated with previous 2,4-D exposure: A cross-sectional study of NHANES III data, 1988-1994'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1289/ehp.0800312',
#    'journal': 'journal-455',
#    'pdf': 'http://europepmc.org/articles/PMC2685835?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2685835'},
#   'title': 'Association of environmental cadmium exposure with periodontal disease in U.S. adults'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2147/COPD.S5237',
#    'journal': 'journal-840',
#    'pdf': 'http://europepmc.org/articles/PMC2672796?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2672796'},
#   'title': 'Life expectancy and years of life lost in chronic obstructive pulmonary disease: Findings from the NHANES III Follow-up Study'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1007/s12245-008-0020-8',
#    'journal': 'journal-841',
#    'pdf': 'http://europepmc.org/articles/PMC2657240?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2657240'},
#   'title': 'Tetanus antibody protection among HIV-infected US-born patients and immigrants'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.3390/ijerph7072800',
#    'journal': 'journal-290',
#    'pdf': 'http://europepmc.org/articles/PMC2922726?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2922726'},
#   'title': 'Parenthood--A contributing factor to childhood obesity'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1155/2010/167162',
#    'journal': 'journal-842',
#    'pdf': 'http://europepmc.org/articles/PMC2911619?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2911619'},
#   'title': 'Renal dysfunction, metabolic syndrome and cardiovascular disease mortality'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc07-2348',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC2453673?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2453673'},
#   'title': 'Trends in diabetes, high cholesterol, and hypertension in chronic kidney disease among U.S. adults: 1988-1994 to 1999-2004'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1479-5868-5-9',
#    'journal': 'journal-176',
#    'pdf': 'http://europepmc.org/articles/PMC2275297?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2275297'},
#   'title': 'The change in weight perception of weight status among the overweight: Comparison of NHANES III (1988-1994) and 1999-2004 NHANES'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0084943',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/articles/PMC3879360?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3879360'},
#   'title': 'Prevalence of chronic kidney disease in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2458-5-126',
#    'journal': 'journal-278',
#    'pdf': 'http://europepmc.org/articles/PMC1318457?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC1318457'},
#   'title': 'Patterns of alcohol drinking and its association with obesity: Data from the Third National Health and Nutrition Examination Survey, 1988-1994'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0019657',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/articles/PMC3102055?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3102055'},
#   'title': 'Trends over 5 Decades in U.S. Occupation-Related Physical Activity and Their Associations with Obesity'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0016604',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/articles/PMC3030597?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3030597'},
#   'title': 'Variation in LPA is associated with Lp(a) levels in three populations from the Third National Health and Nutrition Examination Survey'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1617-9625-9-11',
#    'journal': 'journal-843',
#    'pdf': 'http://europepmc.org/articles/PMC3192654?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3192654'},
#   'title': 'Toward improved statistical methods for analyzing Cotinine-Biomarker health association data'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0017345',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/articles/PMC3046148?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3046148'},
#   'title': 'Differences in self-reported health in the Osteoarthritis Initiative (OAI) and Third National Health and Nutrition Examination Survey (NHANES-III)'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1756-0500-4-145',
#    'journal': 'journal-844',
#    'pdf': 'http://europepmc.org/articles/PMC3120697?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3120697'},
#   'title': 'Methodological problem with comparing increases in different measures of body weight'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/ar3864',
#    'journal': 'journal-845',
#    'pdf': 'http://europepmc.org/articles/PMC3446514?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3446514'},
#   'title': 'The relationship between hand osteoarthritis and serum leptin concentration in participants of the third National Health and Nutrition Examination Survey'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1155/2012/518358',
#    'journal': 'journal-464',
#    'pdf': 'http://europepmc.org/articles/PMC3361252?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3361252'},
#   'title': 'Longitudinal associations of leisure-time physical activity and cancer mortality in the Third National Health and Nutrition Examination Survey (1986-2006)'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/s12882-016-0239-1',
#    'journal': 'journal-846',
#    'pdf': 'http://europepmc.org/articles/PMC4784311?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC4784311'},
#   'title': 'Association between insurance status and mortality in individuals with albuminuria: An observational cohort study'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/s12903-017-0335-z',
#    'journal': 'journal-847',
#    'pdf': 'http://europepmc.org/articles/PMC5237218?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC5237218'},
#   'title': 'Association of dental caries and blood lead levels'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2458-14-143',
#    'journal': 'journal-278',
#    'pdf': 'http://europepmc.org/articles/PMC3929131?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3929131'},
#   'title': 'The disease burden associated with overweight and obesity'},
#  {'manual': {'datasets': ['dataset-019'],
#    'doi': '10.1136/bmj.319.7208.478',
#    'journal': 'journal-527',
#    'pdf': 'https://europepmc.org/articles/PMC28199?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC28199/'},
#   'title': 'Population-based study of social and productive activities as predictors of survival among elderly Americans'},
#  {'manual': {'datasets': ['dataset-019'],
#    'doi': '10.1093/geronb/59.1.S34',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/59/1/S34/9908998/S34.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/59/1/S34/645395'},
#   'title': 'The Black/White Disability Gap: Persistent Inequality in Later Life?'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/60.3.S160',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/60/3/S160/1489943/S160.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/60/3/S160/559405'},
#   'title': 'Widow(er) Poverty and Out-of-Pocket Medical Expenditures Near the End of Life'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/62.4.S209',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/62/4/S209/1383923/S209.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/62/4/S209/516053'},
#   'title': 'Baseline health, socioeconomic status, and 10-year mortality among older middle-aged Americans: Findings from the Health and Retirement Study, 1992-2002'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geront/36.3.311',
#    'journal': 'journal-850',
#    'pdf': 'https://academic.oup.com/gerontologist/article-pdf/36/3/311/2081257/36-3-311.pdf',
#    'url': 'https://academic.oup.com/gerontologist/article/36/3/311/705045'},
#   'title': 'Race Differences in Labor Force Attachment and Disability Status'},
#  {'manual': {'datasets': ['dataset-019'],
#    'doi': '10.1093/gerona/53A.4.M251',
#    'journal': 'journal-849',
#    'pdf': 'https://academic.oup.com/biomedgerontology/article-pdf/53A/4/M251/1598714/53A-4-M251.pdf',
#    'url': 'https://academic.oup.com/biomedgerontology/article/53A/4/M251/592682'},
#   'title': 'Physical activity, physical function, and the risk of breast cancer in a prospective study among elderly women'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/51B.2.S53',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/51B/2/S53/1452112/51B-2-S53.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/51B/2/S53/546654'},
#   'title': 'Worker Adaptation and Employer Accommodation Following the Onset of a Health Impairment'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/57.4.S199',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/57/4/S199/1602842/000124SS.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/57/4/S199/593437'},
#   'title': 'Who Expects to Continue Working After Age 62? The Retirement Plans of Couples'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/54B.3.S136',
#    'journal': 'journal-851',
#    'pdf': 'https://europepmc.org/articles/PMC1201047?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC1201047/'},
#   'title': 'At Risk on the Cusp of Old Age: Living Arrangements and Functional Status Among Black, White and Hispanic Adults'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/58.6.S338',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/58/6/S338/1621944/S338.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/58/6/S338/597438'},
#   'title': 'Trends in Scores on Tests of Cognitive Ability in the Elderly U.S. Population, 1993-2000'},
#  {'manual': {'datasets': ['dataset-016', 'dataset-019'],
#    'doi': '10.1093/geronb/58.5.S264',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/58/5/S264/1681374/S264.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/58/5/S264/611334'},
#   'title': 'A Half Century of Longitudinal Methods in Social Gerontology: Evidence of Change in the Journal'},
#  {'manual': {'datasets': ['dataset-019'],
#    'doi': '10.1093/geronb/59.4.S238',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/59/4/S238/9909004/S238.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/59/4/S238/579030'},
#   'title': 'Trajectories of Impairment, Social Support, and Depressive Symptoms in Later Life'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/59.5.P233',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/59/5/P233/1942550/P233.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/59/5/P233/669092'},
#   'title': "Honeymoons and Joint Lunches: Effects of Retirement and Spouse's Employment on Depressive Symptoms"},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/61.1.S24',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/61/1/S24/1460581/S24.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/61/1/S24/550479'},
#   'title': 'Crediting Care or Marriage? Reforming Social Security Family Benefits'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/60.5.P242',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/60/5/P242/1573699/P242.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/60/5/P242/585462'},
#   'title': 'Disparities Among Older Adults in Measures of Cognitive Function by Race or Ethnicity'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/60.2.S93',
#    'journal': 'journal-851',
#    'pdf': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2505177/pdf/nihms47838.pdf',
#    'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2505177/'},
#   'title': 'The Impact of Childhood and Adult SES on Physical, Mental, and Cognitive Well-Being in Later Life'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/60.1.S21',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/60/1/S21/1705482/S21.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/60/1/S21/617656'},
#   'title': 'The Significance of Nonmarital Cohabitation: Marital Status and Mental Health Benefits among Middle-Aged and Older Adults'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/59.1.S25',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/59/1/S25/9908997/S25.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/59/1/S25/645393'},
#   'title': 'Disability and Home Care Dynamics among Older Unmarried Americans'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geronb/61.5.S248',
#    'journal': 'journal-848',
#    'pdf': 'https://academic.oup.com/psychsocgerontology/article-pdf/61/5/S248/9909060/S248.pdf',
#    'url': 'https://academic.oup.com/psychsocgerontology/article/61/5/S248/604069'},
#   'title': 'Parent care and the stress process: Findings from panel data'},
#  {'manual': {'datasets': ['dataset-016'],
#    'doi': '10.1093/geront/48.5.659',
#    'journal': 'journal-850',
#    'pdf': 'https://europepmc.org/articles/PMC2885453?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2885453/'},
#   'title': 'Racial/ethnic differences in the relationship between the use of health care services and functional disability: The Health and Retirement Study (1992-2004)'},
#  {'manual': {'datasets': ['dataset-019'],
#    'doi': '10.1093/aje/kwt097',
#    'journal': 'journal-568',
#    'pdf': 'https://europepmc.org/articles/PMC3783096?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3783096/'},
#   'title': 'Prediction of severe, persistent activity-of-daily-living disability in older adults'},
#  {'manual': {'datasets': ['dataset-009'],
#    'doi': 'isbn:978-3-86558-856-2',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/65861/1/729177734.pdf',
#    'url': 'http://hdl.handle.net/10419/65861'},
#   'title': 'Diversification and determinants of international credit portfolios: Evidence from German banks'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': '10.5282/ubm/epub.13340',
#    'journal': 'journal-853',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/94017/1/sfb-tr15-dp212.pdf',
#    'url': 'http://hdl.handle.net/10419/94017'},
#   'title': 'FDI and Domestic Investment: An Industry-Level View'},
#  {'manual': {'datasets': ['dataset-013'],
#    'doi': 'RePEc:zbw:bubdp1:5197',
#    'journal': 'journal-854',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19677/1/200648dkp.pdf',
#    'url': 'https://ideas.repec.org/p/zbw/bubdp1/5197.html'},
#   'title': 'Industries and the bank lending effects of bank credit demand and monetary policy in Germany'},
#  {'manual': {'datasets': ['dataset-004'],
#    'doi': 'isbn:978-3-95729-037-3',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/100037/1/791673510.pdf',
#    'url': 'http://hdl.handle.net/10419/100037'},
#   'title': 'Consumer cash usage: A cross-country comparison with payment diary survey data'},
#  {'manual': {'datasets': ['dataset-013', 'dataset-010'],
#    'doi': 'isbn:978-3-95729-206-3',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/123697/1/841217971.pdf',
#    'url': 'http://hdl.handle.net/10419/123697'},
#   'title': 'Cyclicality of SME lending and government involvement in banks'},
#  {'manual': {'datasets': ['dataset-015', 'dataset-008'],
#    'doi': 'isbn:978-3-86558-537-0',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/27745/1/607702656.PDF',
#    'url': 'http://hdl.handle.net/10419/27745'},
#   'title': 'Does lowering dividend tax rates increase dividends repatriated?: evidence of intra-firm cross-border dividend repatriation policies by German Multinational Enterprises'},
#  {'manual': {'datasets': ['dataset-006'],
#    'doi': 'isbn:978-3-86558-563-9',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/28393/1/610028421.PDF',
#    'url': 'http://hdl.handle.net/10419/28393'},
#   'title': 'Determinants for using visible reserves in German banks: an empirical study'},
#  {'manual': {'datasets': ['dataset-006'],
#    'doi': 'isbn:978-3-95729-015-1',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/93086/1/779710983.pdf',
#    'url': 'http://hdl.handle.net/10419/93086'},
#   'title': 'Earnings baths by bank CEOs during turnovers'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': '10.2139/ssrn.392681',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19597/1/200309dkp.pdf',
#    'url': 'http://hdl.handle.net/10419/19597'},
#   'title': 'Determinants of German FDI: New Evidence from Micro-Data'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': 'RePEc:ces:ceswps:_1959',
#    'journal': 'journal-855',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/26004/1/538093242.PDF',
#    'url': 'http://hdl.handle.net/10419/26004'},
#   'title': 'Intercompany Loans and Profit Shifting – Evidence from Company-Level Data'},
#  {'manual': {'datasets': ['dataset-006', 'dataset-013', 'dataset-010'],
#    'doi': 'isbn:978-3-95729-041-0',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/100036/1/791674517.pdf',
#    'url': 'http://hdl.handle.net/10419/100036'},
#   'title': "Quantifying the components of the banks' net interest margin"},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': 'isbn:978-3-86558-378-9',
#    'journal': 'journal-855',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19715/1/200803dkp.pdf',
#    'url': 'http://hdl.handle.net/10419/19715'},
#   'title': "The impact of thin-capitalization rules on multinationals' financing and investment decisions"},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': '10.1007/s10797-006-8721-5',
#    'journal': 'journal-263',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/24083/1/dp0476.pdf',
#    'url': 'https://doi.org/10.1007/s10797-006-8721-5'},
#   'title': 'Tax incentives and the location of FDI: evidence from a panel of German multinationals'},
#  {'manual': {'datasets': ['dataset-013'],
#    'doi': 'isbn:978-3-86558-388-8',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19778/1/200801dkp_b_.pdf',
#    'url': 'http://hdl.handle.net/10419/19778'},
#   'title': 'Analyzing the interest rate risk of banks using time series of accounting-based data: evidence from Germany'},
#  {'manual': {'datasets': ['dataset-013'],
#    'doi': 'RePEc:zbw:bubdp1:7569',
#    'journal': 'journal-855',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/26621/1/595167675.PDF',
#    'url': 'http://hdl.handle.net/10419/26621'},
#   'title': 'The price of liquidity: bank characteristics and market conditions'},
#  {'manual': {'datasets': ['dataset-005'],
#    'doi': 'isbn:978-3-95729-202-5',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/122192/1/83979701X.pdf',
#    'url': 'http://hdl.handle.net/10419/122192'},
#   'title': 'The credit quality channel: Modeling contagion in the interbank market'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': '10.1093/jeea/jvx054',
#    'journal': 'journal-274',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/121462/1/837897491.pdf',
#    'url': 'https://academic.oup.com/jeea/article-abstract/16/6/1929/4904295'},
#   'title': 'The organization of knowledge in multinational firms'},
#  {'manual': {'datasets': ['dataset-006', 'dataset-005'],
#    'doi': '10.1007/s10693-007-0017-0',
#    'journal': 'journal-258',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19752/1/200605dkp_b.pdf',
#    'url': 'http://hdl.handle.net/10419/19752'},
#   'title': 'Does diversification improve the performance of German banks? Evidence from individual bank loan portfolios'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': 'RePEc:ces:ceswps:_5414',
#    'journal': 'journal-855',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/113740/1/cesifo_wp5414.pdf',
#    'url': 'http://hdl.handle.net/10419/113740'},
#   'title': 'At Your Service! The Role of Tax Havens in International Trade with Services'},
#  {'manual': {'datasets': ['dataset-013'],
#    'doi': '10.2139/ssrn.493723',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19730/1/200403dkp_b.pdf',
#    'url': 'http://hdl.handle.net/10419/19730'},
#   'title': 'Does capital regulation matter for bank behaviour? Evidence for German savings banks'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': 'RePEc:zbw:bubdp1:4235',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19626/1/200541dkp.pdf',
#    'url': 'http://hdl.handle.net/10419/19626'},
#   'title': 'Trade balances of the central and east European EU member states and the role of foreign direct investment'},
#  {'manual': {'datasets': ['dataset-013'],
#    'doi': '978-3-86558-503-5',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/27688/1/593866134.PDF',
#    'url': 'http://hdl.handle.net/10419/27688'},
#   'title': 'Why do savings banks transform sight deposits into illiquid assets less intensively than the regulation allows?'},
#  {'manual': {'datasets': ['dataset-015', 'dataset-008'],
#    'doi': '10.2139/ssrn.3164103',
#    'journal': 'journal-856',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/145929/1/VfS_2016_pid_7072.pdf',
#    'url': 'http://hdl.handle.net/10419/145929'},
#   'title': 'Transfer pricing as tax avoidance under different legislative schemes'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': '10.5282/ubm/epub.13339',
#    'journal': 'journal-853',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/94181/1/sfb-tr15-dp213.pdf',
#    'url': 'http://hdl.handle.net/10419/94181'},
#   'title': 'Who is afraid of political risk? Multinational firms and their choice of capital structure'},
#  {'manual': {'datasets': ['dataset-013', 'dataset-010'],
#    'doi': '10.1016/j.jfs.2007.04.003',
#    'journal': 'journal-236',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19762/1/200703dkp_b_.pdf',
#    'url': 'http://hdl.handle.net/10419/19762'},
#   'title': 'Slippery slopes of stress: ordered failure events in German banking'},
#  {'manual': {'datasets': ['dataset-006'],
#    'doi': 'isbn:978-3-95729-393-0',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/168589/1/898458471.pdf',
#    'url': 'http://hdl.handle.net/10419/168589'},
#   'title': 'Do all new brooms sweep clean? Evidence for outside bank appointments'},
#  {'manual': {'datasets': ['dataset-013'],
#    'doi': '10.1093/rof/rfu019',
#    'journal': 'journal-857',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/82625/1/768057302.pdf',
#    'url': 'http://hdl.handle.net/10419/82625'},
#   'title': 'Bank risk taking and competition: Evidence from regional banking markets'},
#  {'manual': {'datasets': ['dataset-013', 'dataset-010'],
#    'doi': '10.1016/j.jbankfin.2006.12.009',
#    'journal': 'journal-240',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19742/1/200509dkp_b.pdf',
#    'url': 'http://hdl.handle.net/10419/19742'},
#   'title': 'Accounting for distress in bank mergers'},
#  {'manual': {'datasets': ['dataset-013', 'dataset-010'],
#    'doi': '10.2139/ssrn.726408',
#    'journal': 'journal-858',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19745/1/200512dkp_b.pdf',
#    'url': 'http://hdl.handle.net/10419/19745'},
#   'title': 'Evaluating the German bank merger wave'},
#  {'manual': {'datasets': ['dataset-013', 'dataset-010'],
#    'doi': '10.2139/ssrn.700751',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19734/1/200501dkp_b.pdf',
#    'url': 'http://hdl.handle.net/10419/19734'},
#   'title': 'Measurement matters: Input price proxies and bank efficiency in Germany'},
#  {'manual': {'datasets': ['dataset-005'],
#    'doi': 'RePEc:zbw:bubdp2:7449',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/27670/1/200818dkp_b_.pdf',
#    'url': 'http://hdl.handle.net/10419/27670'},
#   'title': 'Real estate markets and bank distress'},
#  {'manual': {'datasets': ['dataset-013', 'dataset-010'],
#    'doi': '10.2139/ssrn.958509',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19761/1/200702dkp_b_.pdf',
#    'url': 'http://hdl.handle.net/10419/19761'},
#   'title': 'Efficient, profitable and safe banking: an oxymoron? Evidence from a panel VAR approach'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': '10.1111/caje.12061',
#    'journal': 'journal-859',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/27746/1/607703962.PDF',
#    'url': 'http://hdl.handle.net/1814/7164'},
#   'title': 'Export-Supporting FDI'},
#  {'manual': {'datasets': ['dataset-005'],
#    'doi': '10.2139/ssrn.627842',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19732/1/200405dkp_b.pdf',
#    'url': 'http://hdl.handle.net/10419/19732'},
#   'title': 'How will Basel II affect bank lending to emerging markets? An analysis based on German bank level data'},
#  {'manual': {'datasets': ['dataset-005'],
#    'doi': 'RePEc:zbw:bubdp2:7448',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/27669/1/200817dkp_b_.pdf',
#    'url': 'http://hdl.handle.net/10419/27669'},
#   'title': 'Stress testing of real credit portfolios'},
#  {'manual': {'datasets': ['dataset-006', 'dataset-007'],
#    'doi': '10.1016/j.jbankfin.2010.08.003',
#    'journal': 'journal-240',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/40693/1/635916479.pdf',
#    'url': 'http://hdl.handle.net/10419/40693'},
#   'title': "Banks' exposure to interest rate risk, their earnings from term transformation, and the dynamics of the term structure"},
#  {'manual': {'datasets': ['dataset-013'],
#    'doi': '10.1504/IJBAAF.2008.020243',
#    'journal': 'journal-860',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19784/1/200807dkp_b_.pdf',
#    'url': 'http://hdl.handle.net/10419/19784'},
#   'title': 'Which interest rate scenario is the worst one for a bank? Evidence from a tracking bank approach for German savings and cooperative banks'},
#  {'manual': {'datasets': ['dataset-006'],
#    'doi': '10.1016/j.jfi.2009.10.002',
#    'journal': 'journal-235',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19765/1/200706dkp_b_.pdf',
#    'url': 'http://hdl.handle.net/10419/19765'},
#   'title': 'How do banks adjust their capital ratios? Evidence from Germany'},
#  {'manual': {'datasets': ['dataset-006', 'dataset-013', 'dataset-010'],
#    'doi': '10.1111/geer.12131',
#    'journal': 'journal-807',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/142700/1/862557410.pdf',
#    'url': 'http://hdl.handle.net/10419/142700'},
#   'title': "Banks' Interest Rate Risk and Search for Yield: A Theoretical Rationale and Some Empirical Evidence"},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': '10.1007/s10290-005-0052-6',
#    'journal': 'journal-261',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19516/1/200508dkp.pdf',
#    'url': 'http://hdl.handle.net/10419/19516'},
#   'title': 'Location Choice and Employment Decisions: A Comparison of German and Swedish Multinationals'},
#  {'manual': {'datasets': ['dataset-005'],
#    'doi': '10.2139/ssrn.791444',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19741/1/200508dkp_b.pdf',
#    'url': 'http://hdl.handle.net/10419/19741'},
#   'title': 'German bank lending to industrial and non-industrial countries: driven by fundamentals or different treatment?'},
#  {'manual': {'datasets': ['dataset-006', 'dataset-013', 'dataset-005'],
#    'doi': '10.1093/rof/rfy011',
#    'journal': 'journal-857',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/110959/1/827483279.pdf',
#    'url': 'http://hdl.handle.net/10419/110959'},
#   'title': 'Do exposures to sagging real estate, subprime or conduits abroad lead to contraction and flight to quality in bank lending at home?'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': '10.1007/s10290-005-0051-7',
#    'journal': 'journal-261',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/17807/1/kap1252.pdf',
#    'url': 'http://hdl.handle.net/10419/17807'},
#   'title': 'Taxes and the financial structure of German inward FDI'},
#  {'manual': {'datasets': ['dataset-004'],
#    'doi': '10.1515/jos-2017-0021',
#    'journal': 'journal-861',
#    'pdf': 'https://content.sciendo.com/downloadpdf/journals/jos/33/2/article-p427.xml',
#    'url': 'http://www.degruyter.com/view/j/jos.2017.33.issue-2/jos-2017-0021/jos-2017-0021.xml?format=INT'},
#   'title': "The influence of an up-front experiment on respondents' recording behaviour in payment diaries: Evidence from Germany"},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': '10.1111/j.1540-5982.2011.01682.x',
#    'journal': 'journal-862',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/27640/1/200815dkp.pdf',
#    'url': 'https://ideas.repec.org/p/zbw/bubdp1/7555.html'},
#   'title': 'Foreign (in)direct investment and corporate taxation'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': '10.1007/s10797-008-9068-x',
#    'journal': 'journal-263',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/26088/1/53834122X.PDF',
#    'url': 'http://hdl.handle.net/10419/26088'},
#   'title': 'Profit shifting in the EU: Evidence from Germany'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': 'RePEc:zbw:bubdp1:1543',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19469/1/200402dkp.pdf',
#    'url': 'http://hdl.handle.net/10419/19469'},
#   'title': 'Does co-financing by multilateral development banks increase "risky" direct investment in emerging markets\''},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': 'RePEc:zbw:bubdp1:1542',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19468/1/200401dkp.pdf',
#    'url': 'http://hdl.handle.net/10419/19468'},
#   'title': 'Foreign Bank Entry into Emerging Economies: An Empirical Assessment of the Determinants and Risks Predicated on German FDI Data'},
#  {'manual': {'datasets': ['dataset-008'],
#    'doi': 'RePEc:zbw:bubdp1:4208',
#    'journal': 'journal-852',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/19599/1/200311dkp.pdf',
#    'url': 'http://hdl.handle.net/10419/19599'},
#   'title': 'Determinants of German Foreign Direct Investment in Latin American and Asian Emerging Markets in the 1990s'},
#  {'manual': {'datasets': ['dataset-004'],
#    'doi': '10.1007/s00181-013-0708-3',
#    'journal': 'journal-048',
#    'pdf': 'https://www.econstor.eu/bitstream/10419/30032/1/61738505X.pdf',
#    'url': 'https://www.researchgate.net/publication/46454968_Choosing_and_Using_Payment_Instruments_Evidence_From_German_Microdata'},
#   'title': 'Choosing and using payment instruments: evidence from German microdata'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1479-5868-8-20',
#    'journal': 'journal-176',
#    'pdf': 'http://europepmc.org/backend/ptpmcrender.fcgi?accid=PMC3073863&blobtype=pdf',
#    'url': 'http://europepmc.org/articles/PMC3073863'},
#   'title': 'Does perception equal reality? Weight misperception in relation to weight-related attitudes and behaviors among overweight and obese US adults'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1475-2891-10-17',
#    'journal': 'journal-177',
#    'pdf': 'https://nutritionj.biomedcentral.com/track/pdf/10.1186/1475-2891-10-17',
#    'url': 'http://www.nutritionj.com/content/10/1/17'},
#   'title': 'Diet quality is positively associated with 100% fruit juice consumption in children and adults in the United States: NHANES 2003-2006'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1136/jech.46.3.191',
#    'journal': 'journal-479',
#    'pdf': 'https://europepmc.org/articles/PMC1059548?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC1059548/'},
#   'title': 'Gender and race differences in the correlation between body mass and education in the 1971-1975 NHANES I'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/gerona/glp177',
#    'journal': 'journal-849',
#    'pdf': 'https://europepmc.org/articles/PMC2796886?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2796886'},
#   'title': 'Metabolic syndrome and weight gain in adulthood'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1289/ehp.0800376',
#    'journal': 'journal-455',
#    'pdf': 'http://europepmc.org/articles/PMC2685842?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2685842'},
#   'title': 'Bisphenol A data in NHANES suggest longer than expected half-life, substantial nonfood exposure, or both'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.3390/ijerph6031095',
#    'journal': 'journal-290',
#    'pdf': 'http://europepmc.org/backend/ptpmcrender.fcgi?accid=PMC2672402&blobtype=pdf',
#    'url': 'http://europepmc.org/articles/PMC2672402'},
#   'title': 'Disparities in health care utilization by smoking status--NHANES 1999-2004'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.3390/ijerph7093332',
#    'journal': 'journal-290',
#    'pdf': 'http://europepmc.org/backend/ptpmcrender.fcgi?accid=PMC2954548&blobtype=pdf',
#    'url': 'http://europepmc.org/articles/PMC2954548'},
#   'title': 'An examination of the association of selected toxic metals with total and central obesity indices: NHANES 99-02'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc07-2010',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/backend/ptpmcrender.fcgi?accid=PMC2518340&blobtype=pdf',
#    'url': 'http://europepmc.org/articles/PMC2518340'},
#   'title': 'Mitigating case mix factors by choice of glycemic control performance measure threshold'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2458-7-294',
#    'journal': 'journal-278',
#    'pdf': 'http://europepmc.org/backend/ptpmcrender.fcgi?accid=PMC2175513&blobtype=pdf',
#    'url': 'http://europepmc.org/articles/PMC2175513'},
#   'title': 'Consistency between education reported in health survey and recorded in death certificate'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0030093',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/backend/ptpmcrender.fcgi?accid=PMC3266254&blobtype=pdf',
#    'url': 'http://europepmc.org/articles/PMC3266254'},
#   'title': 'Associations between organochlorine pesticides and vitamin D deficiency in the U.S. population'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.5402/2012/691486',
#    'journal': 'journal-863',
#    'pdf': 'http://downloads.hindawi.com/archive/2012/691486.pdf',
#    'url': 'https://www.hindawi.com/journals/isrn/2012/691486/'},
#   'title': 'Factors associated with vitamin D deficiency and inadequacy among women of childbearing age in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0036171',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/backend/ptpmcrender.fcgi?accid=PMC3340351&blobtype=pdf',
#    'url': 'http://europepmc.org/articles/PMC3340351'},
#   'title': 'Hypertension in women of reproductive age in the United States: NHANES 1999-2008'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0059309',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/backend/ptpmcrender.fcgi?accid=PMC3615020&blobtype=pdf',
#    'url': 'http://europepmc.org/articles/PMC3615020'},
#   'title': 'Trends in low-density lipoprotein cholesterol goal achievement in high risk United States adults: Longitudinal findings from the 1999-2008 National Health and Nutrition Examination Surveys'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1038/sdata.2016.96',
#    'journal': 'journal-864',
#    'pdf': 'https://www.nature.com/articles/sdata201696.pdf',
#    'url': 'https://www.nature.com/articles/sdata201696'},
#   'title': 'A database of human exposomes and phenomes from the US National Health and Nutrition Examination Survey'},
#  {'manual': {'datasets': ['dataset-020'],
#    'doi': '10.1038/sdata.2017.108',
#    'journal': 'journal-864',
#    'pdf': 'https://www.nature.com/articles/sdata2017108.pdf',
#    'url': 'https://www.nature.com/articles/sdata2017108'},
#   'title': 'Spatiotemporal database of US congressional elections, 1896--2014'},
#  {'manual': {'datasets': ['dataset-018', 'dataset-017'],
#    'doi': '10.1161/01.HYP.18.5.598',
#    'journal': 'journal-865',
#    'pdf': 'https://www.ahajournals.org/doi/pdf/10.1161/01.HYP.18.5.598',
#    'url': 'https://www.ahajournals.org/doi/abs/10.1161/01.HYP.18.5.598'},
#   'title': 'Risk factors for hypertension in a national cohort study'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1472-6947-10-16',
#    'journal': 'journal-866',
#    'pdf': 'http://europepmc.org/articles/PMC2850872?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2850872'},
#   'title': 'Application of support vector machine modeling for prediction of common diseases: The case of diabetes and pre-diabetes'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0009694',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/articles/PMC2837749?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2837749'},
#   'title': 'Morbid obesity as a risk factor for hospitalization and death due to 2009 pandemic influenza A(H1N1) disease'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1472-6963-10-68',
#    'journal': 'journal-867',
#    'pdf': 'http://europepmc.org/articles/PMC2846927?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2846927'},
#   'title': 'Cholesterol treatment with statins: Who is left out and who makes it to goal?'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1743-7075-7-16',
#    'journal': 'journal-868',
#    'pdf': 'https://nutritionandmetabolism.biomedcentral.com/track/pdf/10.1186/1743-7075-7-16',
#    'url': 'http://www.nutritionandmetabolism.com/content/7/1/16'},
#   'title': 'Lack of association between dietary fructose and hyperuricemia risk in adults'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1371/journal.pone.0008673',
#    'journal': 'journal-001',
#    'pdf': 'http://europepmc.org/articles/PMC2800195?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2800195'},
#   'title': 'Association of urinary bisphenol a concentration with heart disease: Evidence from NHANES 2003/06'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1001/archgenpsychiatry.2009.164',
#    'journal': 'journal-869',
#    'pdf': 'https://europepmc.org/articles/PMC2917196?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2917196'},
#   'title': 'Blood lead levels and major depressive disorder, panic disorder, and generalized anxiety disorder in US young adults'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1186/1471-2318-9-49',
#    'journal': 'journal-016',
#    'pdf': 'http://europepmc.org/articles/PMC2784762?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2784762'},
# ...
#    'url': 'http://europepmc.org/articles/PMC2628695'},
#   'title': 'Full accounting of diabetes and pre-diabetes in the U.S. population in 1988-1994 and 2005-2006'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/aje/kwn286',
#    'journal': 'journal-568',
#    'pdf': 'http://europepmc.org/articles/PMC2638878?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2638878'},
#   'title': 'Prevalence in the United States of selected candidate gene variants'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1038/sj.ejcn.1602889',
#    'journal': 'journal-299',
#    'pdf': 'http://europepmc.org/articles/PMC2645667?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2645667'},
#   'title': 'Low serum selenium is associated with anemia among older adults in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1289/ehp.9019',
#    'journal': 'journal-455',
#    'pdf': 'http://europepmc.org/articles/PMC1551996?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC1551996'},
#   'title': 'Volatile organic compounds and pulmonary function in the Third National Health and Nutrition Examination Survey, 1988-1994'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1370/afm.214',
#    'journal': 'journal-577',
#    'pdf': 'http://europepmc.org/articles/PMC1466782?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC1466782'},
#   'title': 'Changes in age at diagnosis of type 2 diabetes mellitus in the United States, 1988 to 2000'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1073/pnas.1733839100',
#    'journal': 'journal-043',
#    'pdf': 'http://europepmc.org/articles/PMC193602?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC193602'},
#   'title': 'Effectiveness of diabetes mellitus screening recommendations'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1136/oem.59.8.505',
#    'journal': 'journal-901',
#    'pdf': 'https://europepmc.org/articles/PMC1740336/pdf/v059p00505.pdf',
#    'url': 'https://europepmc.org/articles/PMC1740336'},
#   'title': 'Prevalence and risk factors of work related asthma by industry among United States workers: Data from the Third National Health and Nutrition Examination Survey (1988-94)'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.7448/IAS.15.5.18439',
#    'journal': 'journal-780',
#    'pdf': 'http://europepmc.org/articles/PMC3499900?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3499900'},
#   'title': 'Peripheral blood count abnormalities among patients with hepatitis C in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1002/jbmr.55',
#    'journal': 'journal-940',
#    'pdf': 'http://europepmc.org/articles/PMC3153995?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3153995'},
#   'title': 'Estimates of the proportion of older white men who would be recommended for pharmacologic treatment by the new US National Osteoporosis Foundation guidelines'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc09-1524',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC2827508?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2827508'},
#   'title': 'Prevalence of diabetes and high risk for diabetes using A1C criteria in the U.S. population in 1988-2006'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/eurheartj/ehp487',
#    'journal': 'journal-896',
#    'pdf': 'http://europepmc.org/articles/PMC2838679?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2838679'},
#   'title': 'Normal weight obesity: A risk factor for cardiometabolic dysregulation and cardiovascular mortality'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc09-0713',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC2809278?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2809278'},
#   'title': 'Are hemoglobin levels elevated in type 1 diabetes?'},
#  {'manual': {'datasets': ['dataset-017', 'dataset-019'],
#    'doi': '10.1093/gerona/glp163',
#    'journal': 'journal-849',
#    'pdf': 'http://europepmc.org/articles/PMC2822283?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2822283'},
#   'title': 'Red cell distribution width and mortality in older adults: A meta-analysis'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc09-0341',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC2797985?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2797985'},
#   'title': 'Many Americans have pre-diabetes and should be considered for metformin therapy'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1097/EDE.0b013e3181bb5302',
#    'journal': 'journal-941',
#    'pdf': 'http://europepmc.org/articles/PMC2765221?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2765221'},
#   'title': 'Socioeconomic differentials in immune response'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1359/jbmr.090827',
#    'journal': 'journal-940',
#    'pdf': 'http://europepmc.org/articles/PMC3153395?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3153395'},
#   'title': 'Hyponatremia-induced osteoporosis'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1002/art.24839',
#    'journal': 'journal-942',
#    'pdf': 'http://europepmc.org/articles/PMC2747662?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2747662'},
#   'title': 'Determinants of self-reported health status in a population-based sample of persons with radiographic knee osteoarthritis'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1359/jbmr.090706',
#    'journal': 'journal-940',
#    'pdf': 'http://europepmc.org/articles/PMC3312738?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3312738'},
#   'title': 'Prevalence and trends in low femur bone density among older US adults: NHANES 2005-2006 compared with NHANES III'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1111/j.1365-2796.2010.02248.x',
#    'journal': 'journal-943',
#    'pdf': 'http://europepmc.org/articles/PMC3057108?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3057108'},
#   'title': 'Vitamin D deficiency and frailty in older Americans'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/aje/kwp098',
#    'journal': 'journal-568',
#    'pdf': 'http://europepmc.org/articles/PMC2733041?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2733041'},
#   'title': 'Estimating nutrient intake from a food frequency questionnaire: Incorporating the elements of race and geographic region'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc09-0117',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC2713636?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2713636'},
#   'title': 'GHb level and subsequent mortality among adults in the U.S.'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1017/S1368980009005047',
#    'journal': 'journal-282',
#    'pdf': 'http://europepmc.org/articles/PMC3156672?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3156672'},
#   'title': 'Neighbourhood ethnic composition and diet among Mexican-Americans'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc10-0898',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC2963497?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2963497'},
#   'title': 'Racial/ethnic differences in association of fasting glucose-associated genomic loci with fasting glucose, HOMA-B and impaired fasting glucose in U.S. adult population'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1359/JBMR.081242',
#    'journal': 'journal-940',
#    'pdf': 'http://europepmc.org/articles/PMC3312737?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3312737'},
#   'title': 'Dietary calcium and serum 25-hydroxyvitamin D status in relation to BMD among U.S. adults'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1097/AOG.0b013e31818638b5',
#    'journal': 'journal-108',
#    'pdf': 'http://europepmc.org/articles/PMC2610423?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2610423'},
#   'title': 'Cardiovascular disease risk profiles in women with histories of gestational diabetes but without current diabetes'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc08-0801',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC2551643?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC2551643'},
#   'title': 'Association of C-reactive protein with reduced forced vital capacity in a nonsmoking U.S. population with metabolic syndrome and diabetes'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc10-0879',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC3005489?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3005489'},
#   'title': 'Persistent increase of prevalence of metabolic syndrome among U.S. adults: NHANES III to NHANES 1999-2006'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc10-1235',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC3005486?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3005486'},
#   'title': 'Performance of A1C for the classification and prediction of diabetes'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1073/pnas.0709487104',
#    'journal': 'journal-043',
#    'pdf': 'http://europepmc.org/articles/PMC2148411?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC2148411'},
#   'title': 'In vitamin B12 deficiency, higher serum folate is associated with increased total homocysteine and methylmalonic acid concentrations'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1289/ehp.9716',
#    'journal': 'journal-455',
#    'pdf': 'http://europepmc.org/articles/PMC1913605?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC1913605'},
#   'title': 'The association between blood lead levels and osteoporosis among adults--Results from the Third National Health and Nutrition Examination Survey (NHANES III)'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1289/ehp.8850',
#    'journal': 'journal-455',
#    'pdf': 'http://europepmc.org/articles/PMC1480505?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC1480505'},
#   'title': 'Trends in the exposure of nonsmokers in the U.S. population to secondhand smoke: 1988-2002'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/cid/cir306',
#    'journal': 'journal-934',
#    'pdf': 'http://europepmc.org/articles/PMC4542754?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC4542754'},
#   'title': 'All-cause, liver-related, and non-liver-related mortality among HCV-infected individuals in the general US population'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1001/jama.2011.861',
#    'journal': 'journal-898',
#    'pdf': 'http://europepmc.org/articles/PMC3731378?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3731378'},
#   'title': 'Temporal trends in the prevalence of diabetic kidney disease in the United States'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1111/j.1469-1809.2011.00664.x',
#    'journal': 'journal-944',
#    'pdf': 'http://europepmc.org/articles/PMC3155612?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3155612'},
#   'title': 'Evidence for age as a modifier of genetic associations for lipid levels'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/ndt/gfr367',
#    'journal': 'journal-945',
#    'pdf': 'http://europepmc.org/articles/PMC3350356?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3350356'},
#   'title': 'Dietary phosphorus intake and mortality in moderate chronic kidney disease: NHANES III'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/ndt/gfq808',
#    'journal': 'journal-945',
#    'pdf': 'http://europepmc.org/articles/PMC3175050?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3175050'},
#   'title': 'Serum phosphorus predicts incident chronic kidney disease and end-stage renal disease'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1503/cmaj.110387',
#    'journal': 'journal-360',
#    'pdf': 'http://europepmc.org/articles/PMC3185097?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3185097'},
#   'title': 'Using the Edmonton obesity staging system to predict mortality in a population-representative cohort of people with overweight and obesity'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2188/jea.JE20100142',
#    'journal': 'journal-946',
#    'pdf': 'http://europepmc.org/articles/PMC3899432?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3899432'},
#   'title': 'Socioeconomic status, self-rated health, and mortality in a multiethnic sample of US adults'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/aje/kwq367',
#    'journal': 'journal-568',
#    'pdf': 'http://europepmc.org/articles/PMC3105433?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3105433'},
#   'title': "Trends in cardiovascular risk factor levels in the Minnesota Heart Survey (1980-2002) as compared with the National Health and Nutrition Examination Survey (1976-2002): A partial explanation for Minnesota's low cardiovascular disease mortality?"},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc11-0178',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC3120172?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3120172'},
#   'title': 'Long-term and recent progress in blood pressure levels among U.S. adults with diagnosed diabetes, 1988-2008'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/ndt/gfr022',
#    'journal': 'journal-945',
#    'pdf': 'http://europepmc.org/articles/PMC3247860?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3247860'},
#   'title': 'Kidney function, albuminuria and age-related macular degeneration in NHANES III'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2337/dc11-1405',
#    'journal': 'journal-300',
#    'pdf': 'http://europepmc.org/articles/PMC3263918?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3263918'},
#   'title': 'Racial/ethnic- and education-related disparities in the control of risk factors for cardiovascular disease among individuals with diabetes'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1136/bmjopen-2011-000494',
#    'journal': 'journal-305',
#    'pdf': 'http://europepmc.org/articles/PMC3289985?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3289985'},
#   'title': 'Decreased prevalence of diabetes in marijuana users: cross-sectional data from the National Health and Nutrition Examination Survey (NHANES) III'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1093/infdis/jis106',
#    'journal': 'journal-947',
#    'pdf': 'http://europepmc.org/articles/PMC3308905?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3308905'},
#   'title': 'Association between gastric helicobacter pylori colonization and glycated hemoglobin levels'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.2164/jandrol.111.015651',
#    'journal': 'journal-948',
#    'pdf': 'http://europepmc.org/articles/PMC3774012?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC3774012'},
#   'title': 'Association between sex steroid hormones and hematocrit in a nationally-representative sample of men'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1158/1055-9965.EPI-13-0381',
#    'journal': 'journal-107',
#    'pdf': 'http://europepmc.org/articles/PMC4026170?pdf=render',
#    'url': 'https://europepmc.org/articles/PMC4026170'},
#   'title': 'Serum antioxidant nutrients, vitamin A, and mortality in US adults'},
#  {'manual': {'datasets': ['dataset-017'],
#    'doi': '10.1002/oby.20585',
#    'journal': 'journal-220',
#    'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render',
#    'url': 'http://europepmc.org/articles/PMC3866217'},
#   'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity'}]

# %%
title=[]
doi=[]
url=[]
pdf=[]
dataset=[]

# %%
# for song in json_object:
#     # now song is a dictionary
#     for attribute, value in song.iteritems():
#         print attribute, value # example usage

# %%
print(line)
# Out:
# {'manual': {'datasets': ['dataset-017'], 'doi': '10.1370/afm.79', 'journal': 'journal-371', 'pdf': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1466694/pdf/0020351.pdf', 'url': 'http://europepmc.org/articles/PMC5353819'}, 'title': 'Subclinical hypothyroidism and the risk of hypercholesterolemia'}

# %%
print(type(line))
# Out:
# <class 'dict'>

# %%
entry = dict()
entry_list= list()
for line in data:
    for i,v in line.items():
        print(type(line))
        #i = manual, or title
        #v = manual (datasets, doi, journal, pdf, url), or title
        print(v['url'],v['title'])
        
        for ds, doi, pub, pdf, url in i:
            original=dict()
            original['pdf'] = pdf['pdf']
            original['doi'] = doi['doi']
            original['url'] = url['url']
            original['journal'] = pub['journal']
            dataset = list(i['manual']['datasets'])
            entry['original']=original
            entry['dataset'] = dataset
            entry_list.append(entry)
        for title in i:
            entry['title'] = i['title']
print(entry_list)

        
  #  print(line)
   # for i,v in line.items():
        #print(i,v)
# Out:
# <class 'dict'>
# {'datasets': ['dataset-017'], 'doi': '10.1370/afm.79', 'journal': 'journal-371', 'pdf': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1466694/pdf/0020351.pdf', 'url': 'http://europepmc.org/articles/PMC5353819'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-7bc94500539c> in <module>
#       8         print(v)
#       9
# ---> 10         for ds, doi, pub, pdf, url in i:
#      11             original=dict()
#      12             original['pdf'] = pdf['pdf']
#
# ValueError: not enough values to unpack (expected 5, got 1)

# %%
entry = dict()
entry_list= list()
for i in data:
    entry['title'] = i['title']
    original=dict()
    original['pdf'] = i['manual']['pdf']
    original['doi'] = i['manual']['doi']
    original['url'] = i['manual']['url']
    original['journal'] = i['manual']['journal']
    dataset = list(i['manual']['datasets'])
    entry['original']=original
    entry['dataset'] = dataset
    entry_list.append(entry)
print(entry_list)

# code repeating final entry of
# Out:
# [{'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europepmc.org/articles/PMC3866217?pdf=render', 'doi': '10.1002/oby.20585', 'url': 'http://europepmc.org/articles/PMC3866217', 'journal': 'journal-220'}, 'dataset': ['dataset-017']}, {'title': 'The progression of cardiometabolic disease: Validation of a new cardiometabolic disease staging system applicable to obesity', 'original': {'pdf': 'http://europ ...

# %%
with open('bbk_corpus0_1_5_partition.json', 'w') as f_out:
    json.dump(entry_list, f_out, indent=4, sort_keys=True, ensure_ascii=False)
