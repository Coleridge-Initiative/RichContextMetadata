# %% [markdown]
# ## OpenAIRE API Example
# Use the [OpenAIRE API](https://explore.openaire.eu/) to find *open access* PDFs for research publications.

# %% [markdown]
# If needed, install from the `requirements.txt` file:
# ```
# source venv/bin/activate
# pip install -r requirements.txt
# ```

# %% [markdown]
# Toggle this boolean flag to get into debug/test mode...

# %%
DEBUG = False # True

# %% [markdown]
# Here's an iterator to scan the file from the ETL workflow which lists the publications to lookup. NB: the row format may change, check that -

# %%
import csv

def iter_pub (filename):
    with open(filename) as f:
        for row in csv.reader(f, delimiter=","):
            dataset, doi, journal, title = row[:4]
            yield doi, journal, title

# %% [markdown]
# Here's an access function to read content from a URI -- in other words, access an HTTP-based API:

# %%
import urllib.request

def load_uri (uri):
    with urllib.request.urlopen(uri) as response:
        html = response.read()
        return html.decode("utf-8")

# %% [markdown]
# Here's a function that creates a UUID for an entity in the graph. We use a tuple (a set of columns), e.g., `[doi, journal, title]`, with the `hashlib` library. This way, the UUID values are reproduced the same way each time.

# %%
import hashlib

def get_hash (row):
    m = hashlib.blake2b(digest_size=10)
    
    for elem in row:
        m.update(elem.encode("utf-8").lower().strip())

    return m.hexdigest()

# %% [markdown]
# This function uses the title of a publication to run a lookup in the OpenAIR API, yielding the `[doi, pub_id, pub_url, journal, title]` tuple as a result.

# %%
from urllib import parse

API_URI = "http://api.openaire.eu/search/publications?title="

def lookup_pub_uris (iter, debug=False):
    for doi, journal, title in iter:
        if DEBUG:
            print(doi, journal, title)

        xml = load_uri(API_URI + parse.quote(title))

        if DEBUG:
            print(xml)

        pub_url = extract_pub_uri(xml)

        if pub_url:
            pub_id = "publication-{}".format(get_hash([doi, journal, title]))
            yield doi, pub_id, pub_url, journal, title

# %% [markdown]
# Here's an access function that parses the XML output from the OpenAIRE API response, then extracts the URL for the publication's open access PDF -- if it's available.

# %%
import xml.etree.ElementTree as et

NS = {
    "oaf": "http://namespace.openaire.eu/oaf"
    }

def extract_pub_uri (xml):
    root = et.fromstring(xml)
    result = root.findall("./results/result[1]/metadata/oaf:entity/oaf:result", NS)

    if len(result) > 0:
        url_list = result[0].findall("./children/instance/webresource/url")

        if len(url_list) > 0:
            pub_url = url_list[0].text
            return pub_url

    return None

# %% [markdown]
# Now, specific the source data -- or optionally inject a test case instead...

# %%
filename = "../usda/dyads_for_validation.csv"
iter = iter_pub(filename)

if DEBUG:
    iter = [["10.5150/alfred.e.neuman", "Mad Magazine", "Does a Nutritious Diet Cost More in Food Deserts?"]]

# %%
import json

# pull results from the OpenAIRE API                                                                                         
results = [ row for row in lookup_pub_uris(iter, debug=DEBUG) ]
print(json.dumps(results, indent=2))
# Out:
# [
#   [
#     "doi",
#     "publication-61f787206f84063920fb",
#     "http://cds.cern.ch/record/969091",
#     "journal",
#     "title"
#   ],
#   [
#     "10.1111/agec.12444",
#     "publication-e84ab84d25278051773e",
#     "http://purl.umn.edu/205424",
#     "Agricultural Economics",
#     "Does a nutritious diet cost more in food deserts?"
#   ],
#   [
#     "10.1016/j.aaspro.2016.02.014",
#     "publication-0c97553ee24b5584124e",
#     "http://dx.doi.org/10.1016/j.aaspro.2016.02.014",
#     "Agriculture and Agricultural Science Procedia",
#     "Consumer Response to Quality Differentiation Strategies in Wine PDOs"
#   ],
#   [
#     "10.1016/j.wep.2015.12.001",
#     "publication-54a72c05d10975c8ac10",
#     "http://hdl.handle.net/10419/194508",
#     "Wine Economics and Policy",
#     "Wine consumption and sales strategies: The evolution of Mass Retail Trading in Italy"
#   ],
#   [
#     "10.1162/rest_a_00447",
#     "publication-3d5bdb7e22255b2aa07d",
#     "http://www.mitpressjournals.org/doi/pdf/10.1162/REST_a_00447",
#     "Review of Economics and Statistics",
#     "Variety Pass-Through: An Examination of the Ready-to-Eat Breakfast Cereal Market"
#   ],
#   [
#     "10.1162/rest_a_00171",
#     "publication-74b21e814d330dc7ec7b",
#     "http://www.mitpressjournals.org/doi/pdf/10.1162/REST_a_00171",
#     "Review of Economics and Statistics",
#     "Identification With Imperfect Instruments"
#   ],
#   [
#     "10.1002/agr.20058",
#     "publication-4031e6bfc48952880272",
#     "http://purl.umn.edu/25212",
#     "Agribusiness",
#     "Retail oligopoly power, dairy compact, and Boston milk prices"
#   ],
#   [
#     "10.2202/1542-0485.1075",
#     "publication-9e42985c7eb9af12925f",
#     "http://purl.umn.edu/19726",
#     "Journal of Agricultural & Food Industrial Organization",
#     "Market Conduct in the U.S. Ready-to-Eat Cereal Industry"
#   ],
#   [
#     "10.1162/003465303765299792",
#     "publication-87644cc4bf35d538cdd7",
#     "http://www.mitpressjournals.org/doi/pdf/10.1162/003465303765299792",
#     "Review of Economics and Statistics",
#     "New Products, Quality Changes, and Welfare Measures Computed from Estimated Demand Systems"
#   ],
#   [
#     "10.1111/1468-0262.00194",
#     "publication-732f0b91dbf2af919298",
#     "http://www.escholarship.org/uc/item/7cm5p858",
#     "Econometrica",
#     "Measuring Market Power in the Ready\u2010to\u2010Eat Cereal Industry"
#   ],
#   [
#     "10.1016/j.wep.2015.12.001",
#     "publication-54a72c05d10975c8ac10",
#     "http://hdl.handle.net/10419/194508",
#     "Wine Economics and Policy",
#     "Wine consumption and sales strategies: The evolution of Mass Retail Trading in Italy"
#   ],
#   [
#     "10.1093/erae/jbu033",
#     "publication-3acc64f995804dee5827",
#     "http://hdl.handle.net/10.1093/erae/jbu033",
#     "European Review of Agricultural Economics",
#     "Simulating welfare effects of the European nutrition and health claims\u2019 regulation: the Italian yogurt market"
#   ],
#   [
#     "10.1111/j.1467-6451.2008.00330.x",
#     "publication-7a54dba17d186232c543",
#     "http://purl.umn.edu/149024",
#     "Journal of Industrial Economics",
#     "PRICE COMPETITION IN U.S. BREWING*"
#   ],
#   [
#     "10.1017/s1074070800022574",
#     "publication-0457059bf46bb2421e82",
#     "http://purl.umn.edu/43788",
#     "Journal of Agricultural and Applied Economics",
#     "Firm-Level Competition in Price and Variety"
#   ],
#   [
#     "10.1111/j.1467-9353.2006.00317.x",
#     "publication-f63f5694e4f345a4c6db",
#     "http://hdl.handle.net/10.1111/j.1467-9353.2006.00317.x",
#     "Review of Agricultural Economics",
#     "Sales Responses to Recalls for Listeria monocytogenes: Evidence from Branded Ready\u2010to\u2010Eat Meats"
#   ],
#   [
#     "10.1111/j.1574-0862.2006.00136.x",
#     "publication-533d48b9c967f8de3c03",
#     "http://purl.umn.edu/25158",
#     "Agricultural Economics",
#     "Strategic pricing in a differentiated product oligopoly model: fluid milk in Boston"
#   ],
#   [
#     "10.1787/oecd_papers-v2-5-fr",
#     "publication-9b39fcb9884ce33a5a0a",
#     "https://europepmc.org/articles/PMC3369753/",
#     "Documents de l OCDE",
#     "Volume 2, Issue 5"
#   ],
#   [
#     "10.1016/j.appet.2017.07.006",
#     "publication-70d6f8ce67a624557969",
#     "https://europepmc.org/articles/PMC5574185/",
#     "Appetite",
#     "Deal or no deal? The prevalence and nutritional quality of price promotions among U.S. food and beverage purchases"
#   ],
#   [
#     "10.1016/j.jand.2017.01.011",
#     "publication-653a56ab028f409d300f",
#     "https://europepmc.org/articles/PMC5573644/",
#     "Journal of the Academy of Nutrition and Dietetics",
#     "No Fat, No Sugar, No Salt . . . No Problem? Prevalence of \u201cLow-Content\u201d Nutrient Claims and Their Associations with the Nutritional Profile of Food and Beverage Purchases in the\u00a0United States"
#   ],
#   [
#     "10.1016/j.pmedr.2019.100883",
#     "publication-e4d589bb5b97928d10e2",
#     "https://europepmc.org/articles/PMC6522848/",
#     "Preventive Medicine Reports",
#     "Sugar-sweetened beverage prices: Variations by beverage, food store, and neighborhood characteristics, 2017"
#   ],
#   [
#     "10.1093/ajae/aay032",
#     "publication-f08957f9644dbb2bfbf6",
#     "https://europepmc.org/articles/PMC6404774/",
#     "American Journal of Agricultural Economics",
#     "Scanner Data-Based Panel Price Indexes."
#   ]
# ]

# %% [markdown]
# Really, that's all that's needed for the ETL workflow.
#
# The next step would be what we'll do later for knowledge graph generation (as an example with metadata) -- this converts the `results` structure into JSON-LD. Here's a header and template to use as metadata in TTL (intermediate form) during the format conversion.

# %%
TTL_HEADER = """                                                                                                             
@base <https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary> .                                                  
@prefix cito:   <http://purl.org/spar/cito/> .                                                                               
@prefix dct:    <http://purl.org/dc/terms/> .                                                                                
@prefix foaf:   <http://xmlns.com/foaf/0.1/> .                                                                               
@prefix rdf:    <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .                                                              
@prefix xsd:    <http://www.w3.org/2001/XMLSchema#> .                                                                        
"""

PUB_TEMPLATE = """                                                                                                           
:{}                                                                                                                          
  rdf:type :ResearchPublication ;                                                                                            
  dct:title "{}"@en ;                                                                                                        
  dct:identifier "{}" ;                                                                                                      
  dct:language "en" ;                                                                                                        
  foaf:page "{}"^^xsd:anyURI ;                                                                                               
  .                                                                                                                          
"""

# %%
from rdflib import Graph, plugin
from rdflib.plugin import register, Parser, Serializer
import pyld

# format as JSON_LD                                                                                                      
with open("vocab.json", "r") as f:
    CONTEXT = json.load(f)

frags = [TTL_HEADER]

for doi, pub_id, pub_url, journal, title in results:
    frags.append(PUB_TEMPLATE.format(pub_id, title, doi, pub_url))

g = Graph()
g.parse(data="\n".join(frags), format="n3")

jsonld = json.loads(g.serialize(format="json-ld", context=CONTEXT))
jsonld = pyld.jsonld.compact(jsonld, CONTEXT)

print(json.dumps(jsonld, indent=2))
# Out:
# {
#   "@context": {
#     "@language": "en",
#     "@vocab": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#",
#     "authority": "http://id.loc.gov/authorities/subjects/",
#     "cito": "http://purl.org/spar/cito/",
#     "dbpedia": "http://dbpedia.org/resource/",
#     "dcat": "http://www.w3.org/ns/dcat#",
#     "dct": "http://purl.org/dc/terms/",
#     "doi": "https://doi.org/",
#     "fabio": "http://purl.org/spar/fabio/",
#     "foaf": "http://xmlns.com/foaf/0.1/",
#     "iso639": "http://id.loc.gov/vocabulary/iso639-1/",
#     "mads": "http://www.loc.gov/mads/rdf/v1#",
#     "orcid": "https://orcid.org/",
#     "owl": "http://www.w3.org/2002/07/owl#",
#     "pav": "http://purl.org/pav/",
#     "prism": "http://prismstandard.org/namespaces/basic/2.0/",
#     "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
#     "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
#     "skos": "http://www.w3.org/2004/02/skos/core#",
#     "xsd": "http://www.w3.org/2001/XMLSchema#"
#   },
#   "@graph": [
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-0c97553ee24b5584124e",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1016/j.aaspro.2016.02.014"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Consumer Response to Quality Differentiation Strategies in Wine PDOs",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://dx.doi.org/10.1016/j.aaspro.2016.02.014"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-732f0b91dbf2af919298",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1111/1468-0262.00194"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Measuring Market Power in the Ready\u2010to\u2010Eat Cereal Industry",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://www.escholarship.org/uc/item/7cm5p858"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-3acc64f995804dee5827",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1093/erae/jbu033"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Simulating welfare effects of the European nutrition and health claims\u2019 regulation: the Italian yogurt market",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://hdl.handle.net/10.1093/erae/jbu033"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-9e42985c7eb9af12925f",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.2202/1542-0485.1075"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Market Conduct in the U.S. Ready-to-Eat Cereal Industry",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://purl.umn.edu/19726"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-9b39fcb9884ce33a5a0a",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1787/oecd_papers-v2-5-fr"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Volume 2, Issue 5",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "https://europepmc.org/articles/PMC3369753/"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-e4d589bb5b97928d10e2",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1016/j.pmedr.2019.100883"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Sugar-sweetened beverage prices: Variations by beverage, food store, and neighborhood characteristics, 2017",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "https://europepmc.org/articles/PMC6522848/"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-e84ab84d25278051773e",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1111/agec.12444"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Does a nutritious diet cost more in food deserts?",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://purl.umn.edu/205424"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-0457059bf46bb2421e82",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1017/s1074070800022574"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Firm-Level Competition in Price and Variety",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://purl.umn.edu/43788"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-533d48b9c967f8de3c03",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1111/j.1574-0862.2006.00136.x"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Strategic pricing in a differentiated product oligopoly model: fluid milk in Boston",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://purl.umn.edu/25158"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-61f787206f84063920fb",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "doi"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "title",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://cds.cern.ch/record/969091"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-f63f5694e4f345a4c6db",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1111/j.1467-9353.2006.00317.x"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Sales Responses to Recalls for Listeria monocytogenes: Evidence from Branded Ready\u2010to\u2010Eat Meats",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://hdl.handle.net/10.1111/j.1467-9353.2006.00317.x"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-54a72c05d10975c8ac10",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1016/j.wep.2015.12.001"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Wine consumption and sales strategies: The evolution of Mass Retail Trading in Italy",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://hdl.handle.net/10419/194508"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-3d5bdb7e22255b2aa07d",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1162/rest_a_00447"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Variety Pass-Through: An Examination of the Ready-to-Eat Breakfast Cereal Market",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://www.mitpressjournals.org/doi/pdf/10.1162/REST_a_00447"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-7a54dba17d186232c543",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1111/j.1467-6451.2008.00330.x"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "PRICE COMPETITION IN U.S. BREWING*",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://purl.umn.edu/149024"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-74b21e814d330dc7ec7b",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1162/rest_a_00171"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Identification With Imperfect Instruments",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://www.mitpressjournals.org/doi/pdf/10.1162/REST_a_00171"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-87644cc4bf35d538cdd7",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1162/003465303765299792"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "New Products, Quality Changes, and Welfare Measures Computed from Estimated Demand Systems",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://www.mitpressjournals.org/doi/pdf/10.1162/003465303765299792"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-70d6f8ce67a624557969",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1016/j.appet.2017.07.006"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Deal or no deal? The prevalence and nutritional quality of price promotions among U.S. food and beverage purchases",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "https://europepmc.org/articles/PMC5574185/"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-f08957f9644dbb2bfbf6",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1093/ajae/aay032"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Scanner Data-Based Panel Price Indexes.",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "https://europepmc.org/articles/PMC6404774/"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-653a56ab028f409d300f",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1016/j.jand.2017.01.011"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "No Fat, No Sugar, No Salt . . . No Problem? Prevalence of \u201cLow-Content\u201d Nutrient Claims and Their Associations with the Nutritional Profile of Food and Beverage Purchases in the\u00a0United States",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "https://europepmc.org/articles/PMC5573644/"
#       }
#     },
#     {
#       "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#publication-4031e6bfc48952880272",
#       "@type": "ResearchPublication",
#       "dct:identifier": {
#         "@value": "10.1002/agr.20058"
#       },
#       "dct:language": {
#         "@value": "en"
#       },
#       "dct:title": "Retail oligopoly power, dairy compact, and Boston milk prices",
#       "foaf:page": {
#         "@type": "xsd:anyURI",
#         "@value": "http://purl.umn.edu/25212"
#       }
#     }
#   ]
# }

# %% [markdown]
# Overkill, but good to have in hand.
