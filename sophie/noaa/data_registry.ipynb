# %%
'https://www.ncdc.noaa.gov/cdo-web/token'

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://data.noaa.gov/dataset/?q=inundation&sort=score+desc%2C+metadata_modified+desc"

# %%
response = requests.get(url).text
soup = BeautifulSoup(response,  "html.parser")

# %%
class="dataset-item"

# %%
result_list = soup.find_all("li",{"class":"dataset-item"})

# %%
result_list
# Out:
# [<li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/inundation-mapping-tidal-surface-mean-higher-high-water">Inundation Mapping Tidal Surface - Mean Higher High Water</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data are a derived product of the NOAA VDatum tool and they extend the tool's Mean Higher High Water (MHHW) tidal datum conversion inland beyond its original extent....</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  <li>
#  <a class="label" data-format="zip" href="/dataset/dataset/inundation-mapping-tidal-surface-mean-higher-high-water">ZIP</a>
#  </li>
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-sea-level-rise-data-current-mean-higher-high-water-inundatio2">NOAA Office for Coastal Management Sea Level Rise Data: Current Mean Higher H...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online
#  mapping viewer depicting...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  <li>
#  <a class="label" data-format="xml" href="/dataset/dataset/noaa-office-for-coastal-management-sea-level-rise-data-current-mean-higher-high-water-inundatio2">XML</a>
#  </li>
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-sea-level-rise-data-coastal-flood-threshold-inundation-exten">NOAA Office for Coastal Management Sea Level Rise Data: Coastal Flood Thresho...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer depicting...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-sea-level-rise-data-coastal-flood-threshold-inundation-exten1">NOAA Office for Coastal Management Sea Level Rise Data: Coastal Flood Thresho...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online
#  mapping viewer depicting...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-charleston-wfo-ge">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>This digital elevation model (DEM) is a part of a series of DEMs produced for the National Oceanic and Atmospheric Administration Office for Coastal Management's Sea Level Rise...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-jacksonville-wfo-">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>This digital elevation model (DEM) is a part of a series of DEMs produced for the National Oceanic and Atmospheric Administration Office for Coastal Management's Sea Level Rise...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-sea-level-rise-data-current-mean-higher-high-water-inundatio">NOAA Office for Coastal Management Sea Level Rise Data: Current Mean Higher H...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer depicting...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-puerto-rico">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer called the Sea...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-massachusetts">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer called the Sea...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-new-hampshire">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer called the Sea...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-maine-east">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer called the Sea...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-rhode-island">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer called the Sea...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-maryland-north">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer called the Sea...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-lake-charles-texa">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>This digital elevation model (DEM) is a part of a series of DEMs produced for the National Oceanic and Atmospheric Administration Office for Coastal Management's Sea Level Rise...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-virginia-eastern-">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer called the Sea...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-brownsville-texas">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>This digital elevation model (DEM) is a part of a series of DEMs produced for the National Oceanic and Atmospheric Administration Office for Coastal Management's Sea Level Rise...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-san-diego-ca-wfo">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>This digital elevation model (DEM) is a part of a series of DEMs produced for the National Oceanic and Atmospheric Administration Office for Coastal Management's Sea Level Rise...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-new-york-hudson-r">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer called the Sea...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-eureka-ca-wfo-me">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>This digital elevation model (DEM) is a part of a series of DEMs produced for the National Oceanic and Atmospheric Administration Office for Coastal Management's Sea Level Rise...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>, <li class="dataset-item">
#  <div class="dataset-content">
#  <h3 class="dataset-heading">
#  <a href="/dataset/dataset/noaa-office-for-coastal-management-coastal-inundation-digital-elevation-model-south-carolina-ho">NOAA Office for Coastal Management Coastal Inundation Digital Elevation Model...</a>
#  <!-- Snippet snippets/popular.html start -->
#  <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div>These data were created as part of the National Oceanic and Atmospheric Administration Office for Coastal Management's efforts to create an online mapping viewer called the Sea...</div>
#  </div>
#  <ul class="dataset-resources unstyled">
#  </ul>
#  </li>]

# %%
        node = root.find(name)

# %%
                meta["doi"] = self.get_xml_node_value(result, "doi")
