# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('broken_new.csv')

# %%
df.loc[df.title.str.contains('Multinationals')]
# Out:
#      doi  \
# 38   NaN
# 39   NaN
# 130  NaN
# 136  NaN
# 147  NaN
# 169  NaN
# 170  NaN
# 172  NaN
# 185  NaN
# 187  NaN
# 238  NaN
#
#                                                                                                                                   journal  \
# 38    Zeitschrift für Betriebswirtschaft
# 39   Working Paper
# 130  Canadian Journal of Economics
# 136  Review of World Economics
# 147  Working Paper
# 169   Finanzarchiv
# 170  Working Paper
# 172   Economics Letters
# 185   WU International Taxation Research Paper Series (02/2017), available at SSRN Electronic Journal: https://ssrn.com/abstract=2929347)
# 187  National Tax Journal
# 238  Working Paper
#
#                                                                                                                                                                                                                                title  \
# ...

# %%
Multinationals

# %%
df
# Out:
#      doi  \
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# ..   ...
# 213  NaN
# 214  NaN
# 215  NaN
# 216  NaN
# 217  NaN
# 218  NaN
# 219  NaN
# 220  NaN
# 221  NaN
# 222  NaN
# 223  NaN
# 224  NaN
# 225  NaN
# 226  NaN
# 227  NaN
# 228  NaN
# 229  NaN
# 230  NaN
# 231  NaN
# 232  NaN
# 233  NaN
# 234  NaN
# 235  NaN
# 236  NaN
# 237  NaN
# 238  NaN
# 239  NaN
# 240  NaN
# 241  NaN
# 242  NaN
#
#                                                                                          journal  \
# 0    BBk Discussion Paper
# 1    BBk Discussion Paper
# 2    BBk Discussion Paper
# 3    BBk Discussion Paper
# 4    BBk Discussion Paper
# 5    Journal of Banking and Finance
# 6    BBk Discussion Paper
# ...

# %%
df.to_csv(‘new.csv’, encoding=’utf-8-sig’)

# %%
a = df.to_dict('records')

# %%
a
# Out:
# [{'doi': nan,
#   'journal': 'BBk Discussion Paper',
#   'title': 'A Comprehensive View on Risk Reporting: Evidence From Supervisory Data',
#   'dataset': 'dataset-006'},
#  {'doi': nan,
#   'journal': 'BBk Discussion Paper',
#   'title': 'A network analysis of the evolution of the German interbank market',
#   'dataset': 'dataset-027'},
#  {'doi': nan,
#   'journal': 'BBk Discussion Paper',
#   'title': 'A new perspective on the interest rate pass-through to non-maturing accounts',
#   'dataset': 'dataset-012'},
#  {'doi': nan,
#   'journal': 'BBk Discussion Paper',
#   'title': 'A Vectorautoregressive Investment Model (VIM) and Monetary Policy Transmission: Panel Evidence from German Firms',
#   'dataset': 'dataset-185'},
#  {'doi': nan,
#   'journal': 'BBk Discussion Paper',
#   'title': 'Accounting for distress in bank mergers',
#   'dataset': 'dataset-169'},
#  {'doi': nan,
#   'journal': 'Journal of Banking and Finance',
# ...

# %%
json_pub_path = 'test.json'
import json

# %%
with open(json_pub_path, 'w') as outfile:
    json.dump(a, outfile, indent=2)
